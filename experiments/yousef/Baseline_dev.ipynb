# %% [markdown]
# # Baseline_dev

# %%
# public imports
import torch
from torch import nn
from torch import optim

# private imports
import gensim

gensim_model = gensim.models.KeyedVectors.load_word2vec_format(
    '../../data/UCL/embeddings/GoogleNews-vectors-negative300.bin', binary=True
)

embedding_map = gensim_model.key_to_index

path = '../../data/bio/Persuade_postprocessed.json'
import pandas as pd
df = pd.read_json(path)
df.text = df.text.str.replace('[^\w\s]','')
vocab = set(' '.join(df.text.values).split())
# Out:
# /var/folders/_6/scw_50_57tb8mmbpq6ylnl6w0000gn/T/ipykernel_2992/3695259575.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.text = df.text.str.replace('[^\w\s]','')

# %%
for word in vocab:
    if word not in embedding_map:
        print(word)
# Out:
# differentation
# licenes
# stired
# disavenges
# tecnonlgy
# dangres
# timeonce
# swending
# Frontantalis
# efficatly
# greatests
# saidyes
# diverles
# obsticales
# spreding
# fortutious
# assocciated
# completeley
# worklike
# liveabul
# simulationg
# travewled
# diasater
# criticised
# arugued
# apppear
# studants
# plesure
# publicransport
# comprimseThe
# innnovative
# secientisit
# towlering
# sseat
# possile
# collenting
# emtoins
# clubunited
# getiing
# collaberate
# iventions
# Electral
# escpially
# crators
# depper
# indivisual
# Idoh
# proxmity
# 35000
# lettign
# billsclothes
# sleepinduced
# prussure
# mowfuntion
# frocery
# humanliy
# alwats
# eclectronics
# imparing
# expadition
# fathersand
# Additionallystudents
# biggersized
# orbiculariaris
# Secondlystudents
# attentiveand
# nessacary
# anachroism
# transreagional
# overexagerating
# revolutionairy
# terain
# impaBence
# Engneers
# expericance
# associted
# emotioanl
# professer
# drecrease
# flawwed
# leglisation
# maunufacturers
# civilzation
# curiusity
# rocksgasses
# chaets
# 5050
# Clus
# seechs
# dilemas
# srtaying
# personplaceand
# anchent
# expiditions
# studet
# suming
# Colombins
# planetother
# statesAll
# pplace
# approriatins
# emotionallyand
# learnedthey
# canididatesor
# p12
# yse
# alogorithms
# lleagal
# Orleansetc
# cuasing
# phonomanon
# navagational
# suvice
# smilly
# ncsl
# brease
# cutepretty
# cuases
# gavinen
# runnung
# schoking
# aporate
# atmosheric
# instrustor
# disaterous
# tex5ng
# twenteyfour
# imageded
# oppinon
# unindended
# gmaes
# foccus
# ninetyfour
# Rosenthalsays
# efficeint
# goveners
# equivellent
# malte
# studiying
# yourfacial
# happning
# cautiosly
# SkylinesHonda
# conclusionTeachers
# imprestion
# saidIm
# betwwen
# taketherefore
# bannned
# driverassisting
# improive
# newrecognition
# attentionso
# complteing
# conrollers
# driverspassengersand
# 1112
# 63
# dependes
# leasat
# driviing
# keping
# mountfunction
# biast
# gasonline
# yearson
# homelessdoesnt
# practise
# comotional
# belevie
# satarted
# resaerch
# soby
# oressure
# feelling
# proabley
# pixle
# saer
# consculsion
# vioces
# gooten
# perons
# conclusionReduced
# factthese
# planningAll
# nottable
# understans
# wathc
# guidelinefree
# workespecially
# Bradfort
# expertes
# itÃ
# pritty
# eruptiones
# placeand
# decideing
# polluston
# sensores
# queastion
# goesI
# boredem
# desasters
# reasoin
# graduat
# 25yrs
# wellwritten
# negitative
# hellps
# sulfic
# teresstial
# acedements
# clasess
# learnedstudent
# nessicisarly
# aplies
# deicided
# understandabe
# AfricaAsiaHaiti
# petray
# SafeWise
# obtaing
# peoplke
# phonw
# onilne
# isting
# carsbut
# stady
# extracurriular
# disform
# Distruct
# resalts
# professionallycreated
# computuer
# Constitutionparagraph
# disriciminate
# paragrahph
# inmformation
# woork
# laern
# althoghVenus
# buttion
# essentiallty
# carthe
# holidayseasonal
# 95
# alternet
# studyTherefore
# expirens
# discussionElectoral
# articl
# roatatinf
# indepentent
# Dissapointment
# interation
# oberserved
# elecctorial
# Permanetly
# imounded
# statingAstronomers
# desaventage
# pargraphe
# scrapebookpriceless
# oneso
# comfired
# somethingand
# thinh
# BAAAMMM
# dothey
# friendshave
# equale
# anacrinism
# schoolpause
# provied
# Bannings
# iniptitudes
# allwell
# braingames
# conmtribute
# worriedtwo
# examplemy
# dearcitizens
# Comlombia
# withit
# tweks
# situatin
# ifwhen
# TableTennis
# calsses
# tueday
# fahrenheitthe
# responsibilityallow
# elimanating
# gereration
# schoolarship
# characterlise
# cautionsly
# internrt
# somwtimes
# incompletenot
# boreds
# Llff
# docter
# slectors
# learnread
# tramendously
# electory
# walkn
# leraning
# manufactours
# classwok
# Kennedysource
# votesthen
# katchup
# furope
# slife
# 11134345
# studentsare
# attiontion
# interrestiing
# mid1990s
# bicking
# autoaccident
# distions
# llow
# madeit
# efficenty
# 41971
# phoneswe
# weught
# gauarded
# coold
# landface
# 29th
# Haidron
# 40mpg
# joyn
# ashmed
# epolice
# snoyone
# pklaces
# everuthing
# jobyou
# nondemocractiv
# opinian
# 1521
# motorisits
# peoplehaving
# bettermore
# alantic
# Carolinaand
# counrties
# disrioed
# frontalis
# venouse
# comphression
# engimes
# nonfacial
# malking
# implimant
# averyone
# previouslymade
# votersThere
# mindsetIt
# vome
# socitiy
# practising
# faund
# beliee
# campien
# environmentsource
# thoughwe
# capitilize
# elecrion
# candidaates
# driving33062
# personsaid
# maapportionment
# gooan
# perswading
# exploaration
# recessin
# disigne
# reoson
# madeby
# girlfreind
# ofof
# emmisionsjust
# winningWe
# Electoarl
# acceot
# vare
# cacn
# eatten
# invintions
# straightup
# fiting
# corrosire
# parigraph
# automactily
# bisest
# assignements
# logest
# humdred
# systemmaking
# posiblity
# soomth
# Texasthat
# aloong
# reasonof
# passins
# impracticle
# electorialvote
# unbuyable
# atke
# nearrecords
# overcomewhat
# saysSensors
# shuled
# BLOOMED
# textThe
# oringial
# privatepublic
# importantFor
# joyne
# 21st
# livley
# unaccouted
# distrought
# scoreed
# presidention
# evalutes
# presidentmost
# wjhy
# lanform
# gratational
# prsidency
# questionsand
# surroungings
# carewhat
# luky
# Lke
# selfimage
# lifeit
# itS
# vehiclesalso
# sportsactivitys
# iteam
# haping
# caputured
# coleg
# BeijingSource
# end1894
# disaddvantages
# feesable
# assissting
# apprpriations
# simoltaniously
# curasidity
# bussinesses
# FKennedy
# Legalmatch
# depressesd
# jailjust
# Cwhich
# charactersitic
# Sutdies
# existiing
# decress
# Abloish
# nurvice
# accidnent
# additionl
# planest
# misions
# chamged
# loarn
# friendsnot
# assgined
# heho
# Denator
# phiscally
# confusedAlso
# bikinng
# metling
# greaty
# esaier
# ffic
# possibilitys
# indivudal
# othersor
# desied
# milloins
# startedthe
# opperational
# 1960when
# reciaves
# insatnce
# adorible
# purposesof
# impovred
# Franced
# phonesvideo
# herer
# engins
# abondens
# nochance
# crapy
# groundlevel
# alines
# dangereous
# Suburd
# thezebra
# examplewhen
# stateAfter
# personstudentteacher
# teaachers
# dagerous
# groupteam
# Alote
# nondemocrac
# mucle
# extree
# certine
# assignmentstestsand
# majoritys
# partys00
# litereally
# theraphist
# seventyfive
# populraity
# orgwikiMotor_vehicle_fatality_rate_in_US_by_year
# Evenig
# emotionalnally
# daiy
# 35092
# waythat
# uneqe
# instituitons
# HellCat
# tarvels
# manfacturer
# 2976
# ariseI
# ruine
# mulesand
# vape
# oculd
# advanaced
# fatasses
# benifitail
# Cowboing
# schoolmiddle
# situatiuon
# supposwe
# studensts
# predidency
# studends
# slipoed
# timeduring
# tuoched
# laugter
# ditermine
# ojective
# everething
# unmotiving
# Overcorrecting
# feelm
# sucsseed
# votethat
# tehcnolgy
# proprties
# pacient
# planneed
# educatuion
# relliy
# vigerously
# collegeFor
# personshelp
# governmant
# foodpeople
# Ellectoal
# unburried
# horiable
# downtwon
# maore
# taxesand
# college1
# aesy
# werr
# caliores
# impowered
# queations
# thinmk
# friendlyfinding
# enconutered
# natraul
# resoonse
# enavles
# reuces
# Somg
# thusand
# perticular
# selfmotivation
# represenntitives
# rockif
# benefiet
# relieabul
# VOTORS
# perserves
# uncomfertable
# nonsmart
# pruis
# unneccasary
# teachthe
# plure
# experiencesknowledgeand
# adknowlege
# majortiy
# pointout
# 820
# atmoshphere
# blery
# talkIm
# suppoded
# perssure
# dolimiting
# develpoed
# hardhowever
# bakc
# edmission
# politicists
# jamsroad
# votebecause
# peoplefriendly
# nonexsitent
# thoroughlywritten
# inmortant
# manifacture
# relatiiobship
# descion
# useed
# articleit
# sentaor
# Valledpar
# youthenhey
# rhole
# interented
# sincerally
# slautered
# compermize
# studenttechnology
# touramentsfencingboxingreadingwhittlingand
# citiesstatesand
# sportclubseven
# computeranimation
# drivingThe
# mesalandofrms
# cancled
# ocur
# alldriver
# nonbias
# flabergasting
# hvaing
# sargents
# bestlaid
# riduliously
# endeavorsparagraph
# offwith
# carsintensive
# sustainnot
# outby
# Anywaylike
# homes1p2
# recievetherefore
# divr
# permantely
# socializng
# hudred
# aoutonomous
# airplans
# cabon
# maybey
# seesthe
# carchances
# respembles
# catastropy
# supossed
# cocept
# leaening
# activitiesmany
# sbasically
# dusent
# Canadiates
# mannually
# dummest
# solvedAlthough
# aritcle
# Leanardo
# Heyhow
# rightabolish
# transportaiont
# illadvised
# 38
# americ
# Zakhareuski
# unfait
# prodess
# consertrate
# wanned
# ineresting
# summerbut
# clasified
# chaneg
# meaninfuly
# thereafterNow
# gamesand
# Collegethere
# havinng
# buyong
# statespassage
# therre
# Therere
# thereThey
# envirorment
# feters
# futer
# tecnlogty
# feelsbut
# electionto
# smileworryor
# Transpotation
# nonrenuable
# anybodythere
# photograh
# expireneced
# gicen
# SAIDIN
# besically
# choaic
# wayssides
# spaceshuttle
# cheaked
# awareded
# reaosn
# wasd
# eletric
# sicence
# anilmals
# releave
# fiaaco
# accully
# Beijjing
# peresident
# organisum
# amongside
# 487
# winnere
# bounderie
# computerbased
# reviws
# schoolmaking
# diffrents
# streering
# Eckmen
# Systemcan
# humanless
# endevaors
# TEOC
# stion
# oppurtnites
# traspotantion
# emissionsjust
# MoreoverCitizens
# optionsometimes
# invisions
# enteratinment
# Paragrapgh
# inschoolsuspensions
# Surveyers
# toexplore
# crontribute
# comepletly
# classput
# felllow
# Sectin
# privledes
# bightest
# buisnesess
# beoveruled
# electeing
# distarcted
# beneficient
# cerainty
# timetrip
# ectoral
# travelingi
# clssroom
# enither
# comenest
# muslces
# tempreature
# hhe
# Citizensvoters
# mosly
# candidte
# outofcontrol
# steping
# whatÂs
# consiter
# dedense
# stugles
# Senilely
# efficted
# carage
# yourselfthen
# eruptiing
# tolk
# rebuted
# benificaial
# plugincars
# electorshave
# boatand
# goand
# presidecial
# wittnessed
# beleieve
# randomMany
# deatail
# tactus
# Baymax
# apperes
# fanizitic
# programI
# allowthe
# independentminded
# fulcutated
# situationas
# drownes
# recouces
# suummer
# Anothere
# untiil
# coumputers
# carcar
# wellplaned
# wonn
# waterThey
# encouriging
# theated
# Secondlyhaving
# diffrece
# aproximatly
# safetest
# Howdo
# malfuncitons
# ELECTORS
# trueThe
# llook
# twoits
# rotton
# hoope
# unrational
# 1979
# prefernce
# turndownit
# posibilty
# ahigher
# sizeso
# fiascoThe
# impotan
# demestration
# examble
# kidsmy
# ThirdWhen
# menaing
# seriouslyespecially
# watere
# candidatesBig
# exapmple
# librities
# woner
# comfactcheckfineusingcellphoneswhiledriving
# invenstment
# emotionAlto
# fourtyfour
# IntroThe
# endore
# responbilities
# avdvances
# simlie
# fels
# timeSummer
# mhite
# manipulted
# forgetand
# palice
# congresssenatorsrepresentatives
# RepublicansDemocrats
# popularand
# questionsget
# expirimental
# Generic_school
# computercontrolled
# unfairoutdated
# appolgized
# winnertakeallsystem
# isint
# chidern
# releasead
# timebut
# tachnologies
# 538number
# destantion
# baseballbasketballtrack
# omm
# thereRadar
# senosor
# deiliver
# peoplehomeless
# tretorous
# daamge
# frncing
# safeand
# agruements
# Bombgerger
# disscussion
# statedThe
# activitiesall
# picuters
# massesbut
# conclued
# priceLEGOsthey
# transportaiton
# incepient
# secondsjust
# inproven
# corbond
# ninetyseven
# atmsophere
# 300
# mait
# undesputibly
# Elctorial
# frot
# electedpresidents
# naufacturer
# machene
# Kennedyp11
# somethingso
# Survetor
# smog70
# HiMy
# gegng
# callschats
# whateveror
# requirence
# 22take
# shadowlike
# 2012to
# par5
# envirment
# delegtion
# completen
# 53
# interprutation
# PersontoPerson
# studient
# systemMilkyway
# likelylead
# sunthis
# mulBtasking
# popullated
# saysScientists
# 22011
# ghdespitehandsfreelawarticle_46c583896c1452768b514324e32d4139
# antienvironmentalism
# LastlyVoting
# treally
# sefldriving
# enator
# decet
# dontlike
# inhapitable
# artsoccerfootballgolf
# EarthP4
# contenue
# consetiment
# negatibe
# fantasticwait
# automatci
# dissipointing
# 1100
# youvote
# smaile
# Idahosays
# 415
# sosince
# inventer
# createa
# Retuters
# competitave
# aspex
# pnones
# city10How
# advanncemet
# becuae
# harmeed
# geogrpahy
# emissionsDuffer
# resuply
# Lisahe
# Overpopulated
# tikets
# moprning
# extrarricular
# expressins
# conditiions
# advancedment
# bome
# electionsthe
# 44th
# nicerlooking
# recessionbecause
# talleys
# Frizzles
# emisisons
# affter
# avertid
# experinental
# throughtrying
# contrie
# thatthats
# systematicaly
# history1
# secinds
# technologyThis
# priocess
# madeinstead
# infrom
# beacauese
# uphead
# convinent
# repaced
# ttrough
# qualilfied
# restrants
# topicsome
# Northeastecthas
# grusgt
# 51998
# effciant
# gigga
# privlege
# Nisaan
# Decressing
# uasage
# paragraph20
# comortable
# MArs
# congestian
# kniw
# opinionsadvice
# Selfesteem
# gthis
# teensafe
# Hihg
# gravit
# jeopardising
# Chinaover
# hersle
# FahrenheitAtmospheric
# hostiptal
# horible
# accominate
# bren
# pargagraph
# dipute
# Thoughs
# hours2
# thisstudents
# acdemics
# computersanimated
# purposley
# liveing
# motorised
# neerby
# 2paragraph
# jointhe
# 83
# Thatll
# caidate
# activetylike
# somedbody
# intelleget
# blunty
# tremondus
# distrabution
# doesint
# proccessnot
# bakeoffs
# gGlobal
# planetThe
# donkeybut
# humainity
# pictuure
# teentoteen
# Plazas3p24
# Congerssional
# giveing
# Bombergerthought
# egyptianstyle
# drvieweays
# possiblesolution
# opstical
# identifys
# elctives
# withwhich
# rhorses
# visinity
# winand
# opritunity
# adiou
# rulesthe
# colledgefor
# preisdential
# flaberghasted
# ffr
# toays
# examole
# importamt
# Beackman
# compines
# comfterable
# paragrapghs
# boxingreadingwhittingand
# raidation
# comperhending
# upthan
# copmputers
# solidier
# Dissapearene
# becasse
# authorWhat
# assocaited
# thingbor
# indead
# pursuited
# previlages
# scienists
# CONCLUTION
# impendiments
# probvably
# helecopters
# outhere
# largerrole
# respinsibility
# SeasGreeceand
# resimay
# LifeForm
# notifaction
# farenhiet
# Lucily
# coservaton
# statesWhat
# trustbut
# resoloution
# comminute
# electorthe
# proabaly
# 10he
# 14yearold
# gettiing
# exauhsted
# Cumputers
# eightit
# Venusthey
# stepbystep
# stessed
# costructs
# diesnt
# beceause
# RunOff
# accecpt
# frew
# campains
# askwhat
# livestockclean
# requirs
# blamd
# imside
# unsatified
# environmentRosenthal
# informationgain
# dosenÃÂt
# reasonsopinions
# imfomation
# discision
# CaliforniaNevadaFlorida
# citicens
# tird
# Exsploring
# hiddenby
# sevendy
# sevive
# pressidential
# folur
# 100mph
# stupiest
# whowhat
# delishous
# udated
# cercumstances
# voiceactivated
# 51Because
# shappy
# volcanoespowerfull
# similaritys
# wde
# flippedclassroom
# veiwers
# scraed
# decearn
# negitve
# songThe
# orbicaularis
# actuallyThe
# sketchual
# revoluntionary
# smogging
# thishe
# closert
# ecomically
# toxicated
# baverage
# knolw
# presidnecy
# caluate
# aftoen
# ovily
# 5000
# opppurtunity
# particuraly
# accidients
# extratrestrialls
# tempoture
# egsist
# designedproject
# thimk
# Proplusion
# throughor
# likeshobbiesand
# alfound
# enviormental
# carsSource
# Dispit
# colosal
# dectetive
# limitng
# saidLuke
# Lsia
# turnning
# gonaa
# ThirdPeople
# glich
# supirior
# disaplined
# dixode
# fastSirens
# useSource
# exsost
# caiotic
# Dolethe
# Survayor
# coolits
# ifetime
# 1800s
# studnents
# plceses
# assunc
# inequallity
# adventuresvisit
# Anothernexample
# Yourre
# itBut
# resonible
# raods
# reprogrammming
# sourcesalso
# EuropeChinaand
# cemicals
# stressSelsky
# instenses
# wethe
# appealand
# yearbookOr
# councler
# fantacized
# impunded
# thinkthat
# brutte
# peopleSource
# themseveles
# worldutilize
# narriator
# rsulted
# casuse
# Colimbia
# metere
# oppen
# perpared
# schoolingfunding
# countrires
# acknowledgeable
# responcible
# hurtthats
# tardyabsent
# realizie
# unknows
# 112
# woulg
# whiledue
# somethere
# compate
# malAppointment
# inovating
# lo0ve
# hgih
# Oddshaped
# destanations
# pollutionas
# matenience
# felxability
# educeted
# ruduced
# 72
# internetor
# sayJust
# prepaed
# fifve
# mmight
# agrguemnt
# densitysize
# youi
# 43
# cevilians
# ohone
# westeren
# atually
# compuster
# collegeIt
# difficalty
# Nonrenewable
# emphasise
# systemvoter
# updataed
# reprogramed
# Kenennedy
# dening
# AFlCIO
# taxtridesharing
# presidentbut
# automobiel
# activateprogram
# oneto
# procastinate
# unviersal
# Sturnguist
# diseles
# caimpaign
# conitinue
# secroty
# smogfree
# Emplimenting
# consideres
# companiesdepending
# worklive
# transportationWhen
# helpGoogle
# conflcts
# youreself
# speakingsocial
# eleviate
# capablity
# sapce
# morebut
# imact
# usethis
# endevor
# ilegaly
# notifys
# sutibole
# deth
# fourtyseven
# mechanuics
# ivestment
# spacesship
# ofver
# pluse
# nonverble
# beneiful
# phenominon
# essaypaper
# preveiw
# unessesary
# mahjority
# accedent
# 150
# recoginize
# rediculus
# soccerbaseballTrack
# suburbed
# activityto
# canidiate
# manfucaturer
# icentive
# Sincearly
# senetors
# gloriuos
# planetery
# relacts
# lowared
# convesation
# detecters
# fasterbreakingand
# wayVauban
# occational
# deapths
# pocition
# 136
# prepring
# expressionPh9
# oddnumbers
# helpm
# Someting
# incar
# accelerte
# pretisipate
# Mayby
# reched
# neurtral
# tnd
# healthty
# landscape5
# Proupulsion
# respondsibly
# majic
# hodtile
# refeused
# lisas
# aesier
# walet
# groupsand
# TampaFL
# collegeFive
# opition
# expieriance
# crowsfeet
# unloadedThe
# electoirial
# levelin
# Espescially
# generatons
# apperciative
# jusst
# absolutel
# assiant
# regionsbut
# housesairplanesor
# repilcate
# backthen
# consulers
# examplewe
# anylize
# technologywith
# Plumerduring
# driveing
# littile
# tempretures
# indivulas
# earthalmost
# numourus
# worknot
# rescid
# nonbenefits
# tehse
# miting
# trasportant
# semipossible
# compareed
# boared
# DearFlorida
# passengee
# overcorrects
# TheyÃ
# engeneering
# alsobecause
# potitive
# actuially
# somore
# studennts
# Martail
# genreal
# 6In
# muscledetecting
# SecondAnother
# fascniated
# delightment
# uneasines
# swaped
# fincing
# detoriate
# WallMart
# responable
# fobidding
# PlazaSource
# understandinglearning
# wayNot
# transportatio
# benifitcial
# Presntly
# camrea
# dfferent
# cornoavirus
# 3When
# poplaur
# GuardChild
# ideasfor
# 175500
# basicallly
# Theren
# emissionsparagraph
# friendsthen
# debry
# despiote
# gvin
# spuriouse
# spme
# gaspowered
# unlikeley
# handeye
# electronicas
# ruiten
# sevenGoogle
# rincles
# ellude
# canvis
# lisin
# docotrs
# lowerclass
# cloudly
# baseballvolleyballand
# thinfs
# Skepticsarticle
# UUnited
# PresidentYou
# resluting
# thwta
# milemay
# alyways
# emotionas
# endeavours
# eperience
# apporximately
# scienetists
# nicemaking
# emotionreading
# governize
# factorLike
# terrian
# uniquet
# convienience
# baseballwrestlingsoccer
# specialSo
# factis
# extracurricullar
# europethe
# trafficed
# esqusite
# disastorous
# thisbut
# PresidentHouse
# supposly
# woundering
# bikeso
# streatsd
# pargarh1
# highlearning
# unbeliveble
# guidince
# motars
# bimplike
# balnets
# sayingMany
# highl
# qould
# tecknology
# tooalso
# existince
# updateing
# isbecause
# exidting
# soucced
# equvialent
# reexplain
# relsed
# Syestem
# hmy
# ÃÂThe
# libability
# materialand
# likedislike
# woderd
# opioion
# multitiude
# yeara
# haveare
# projectI
# playignvideo
# motorvehicle
# eect
# Secondif
# moutheyesnoesand
# efficencess
# schollers
# expresson
# precisemaybe
# timeBut
# everydaybut
# dontknow
# prtecting
# 403ft
# suppprt
# friendsthe
# buuild
# friendDon
# 1503
# com7reasonsnottotextanddrive
# eurge
# redcued
# hidde
# comhandsfreelaw
# beforein
# enigineers
# Dispice
# Technoldgy
# construts
# imantion
# nearrly
# taransportation
# winnerin
# hiumans
# Elelectoral
# Imaybe
# proposterus
# encorperate
# Yesthe
# statesNot
# theair
# She83
# Althouth
# venuis
# 312011
# fastCongestion
# instagram
# confidentually
# emomtions
# resoring
# cheakout
# distrac5on
# fencingboxingreadingwhittingand
# Adavntages
# pillution
# overcomethe
# thrustfull
# verywell
# poblem
# axiety
# transportationSelsky
# pullated
# tospace
# considereation
# attenetion
# maulfunction
# becausewhile
# reallybad
# indivudals
# classroomholding
# worldand
# advicedont
# numberes
# essencial
# Unfortionly
# youst
# extracurrcalum
# lsot
# fastnacting
# nonuseful
# smalll
# desgned
# Romneywas
# putiing
# calledwas
# mulitlple
# develpoing
# waysbut
# figfure
# Electroal
# technologoy
# eventhey
# rightbecause
# Artical
# exicting
# communicaton
# excerbate
# benfeits
# promotingprotection
# eyebags
# impactinf
# strugles
# animalsdont
# compurer
# passageDiesel
# Illinoshas
# computrized
# ofdifferent
# tennisfencingboxingreadingwhittling
# elcetionIn
# snacksthere
# workthey
# enssure
# sampls
# reginon
# groupstools
# cleanding
# eightyeight
# tomorrowI
# Extraculicalar
# facot
# Aviod
# opertunuty
# quitness
# comstorymoneycars20140328cellphoneuse1in4carcrashes70185
# poroving
# foundly
# Wellwhere
# passageWhat
# landscapeParagraph
# Valleduparand
# husbad
# naturaly
# individuwal
# curosity
# difficutly
# Cloumbia
# instints
# stroms
# pedenstrians
# skined
# detec
# manslotter
# lightblub
# metior
# have1
# diesls
# Sincerlytherefor
# statesOnly
# canwill
# goodbecause
# homeworkchours
# diriving
# predidental
# 20500
# percetage
# respectives
# emotisons
# 12am
# irrationalListen
# ingetting
# Eventully
# pharagrapgh
# maior
# oceance
# deleations
# spacerafts
# biggers
# peoplefor
# instences
# chanllege
# colect
# scientst
# cattleboatr
# Senceirly
# blimplike
# saysour
# votersin
# extracise
# castsource
# fascinatesx
# insatiately
# 1st8th
# suppliesanimalsand
# teather
# personand
# picturepainting
# Siliscon
# apnosphere
# repotedly
# simiple
# agsausted
# SuprasChevy
# resonsons
# activityi
# efficiantly
# recommaning
# lowerer
# presideng
# suggetion
# sensers
# cadidat
# formaton
# restarunts
# youR
# eplore
# mesalanforms
# thecomputer
# proplem
# JUst
# advarage
# statesPosner
# youldt
# manualy
# tteam
# proffessionals
# peoplevoters
# LIDARspinning
# clasas
# draginsand
# inspirednot
# askthe
# take2
# pleniful
# alote
# easil
# anyhwhere
# timetaking
# reatining
# Techonolgy
# respondto
# disaprove
# devoleped
# frenchspeaking
# cusin
# tthere
# astriod
# landforming
# airthink
# legislatues
# Sepmber
# regonal
# Cpllege
# humn
# MillerZois
# particiate
# speads
# Electrol
# thionk
# humons
# Firstpeople
# askedIt
# dnagers
# extacurricular
# anone
# soemthign
# bloodalcohol
# europegreecechinavenice
# twosear
# nonlike
# potientally
# vehucles
# carperson
# dangerouse
# Thec
# restrctions
# saysNew
# atheltics
# soemthimes
# shoudnt
# undersatnd
# hazar
# mindbut
# nervewrecking
# survice
# applicible
# ragion
# phenonmon
# heatfriction
# elcectors
# revoles
# suberbs
# otherit
# precedure
# ideasyoull
# movemnets
# somebigger
# Hunag
# 2040
# anachorism
# noncounted
# studeys
# invarable
# baicsally
# themfeed
# reacap
# exceptios
# opiniondriverless
# decisionschoices
# mecto
# descraction
# recuced
# conciderd
# salustion
# hometheyll
# leasurely
# innovtion
# peopleIts
# theier
# sentenes
# tosometimes
# PhonesNow
# Nibu
# techknowleg
# wonnderful
# frenids
# literers
# chaange
# eightteen
# featuresas
# suggedts
# Incar
# carsfor
# atvantage
# selectingvoting
# confusebored
# nutriton
# nedraska
# weither
# alrightyoull
# rudeand
# difinitively
# centurythe
# woyming
# Arestotle
# PresidentThe
# Stoneand
# neather
# Velledupar
# USAschools
# conists
# jobswhat
# cuntires
# musclethe
# Espeically
# interestingbecause
# in1947
# marsand
# advenced
# woulf
# characteristcis
# bennifical
# cogress
# manwoman
# appraite
# disabilaties
# studyng
# spous
# Alsocar
# eupting
# incorparates
# endavors
# slowley
# awayIt
# pracitce
# sitesand
# indpependantly
# higherlevel
# nominimal
# topicthey
# manufacturating
# thisa
# wrng
# Lousina
# unsterstanding
# issuehave
# realand
# doLevey
# mightve
# anypoint
# intrusts
# FinallyIn
# virutues
# eduteendrivingsafetydistracteddrivingresearchXe_nJhKjHo
# immedantly
# focased
# countriesmillions
# commtions
# travaling
# Vauba
# opoion
# generalI
# runningplayingjumping
# congreses
# imfomr
# activitieshobbies
# indepthy
# ddriverless
# carrrying
# persentage
# Donalso
# enjoed
# makeSeeking
# articleOften
# Propultion
# momshe
# contribuation
# brout
# fosil
# assisating
# theroy
# licences
# behindn
# relise
# wastnt
# herhim
# ablle
# themeven
# soid
# voteand
# exceptiable
# respatory
# 152011
# selve
# delcares
# componets
# transportsion
# ssensors
# losest
# faceThe
# articleIn
# explainUsing
# leway
# accecible
# exemplies
# sideffects
# risorious
# profetionals
# pisa
# citiesfor
# friendbrother
# HuangA
# opportunityof
# Statesfourth
# privatly
# freiend
# activitiys
# oppurtunies
# soicety
# atmospere
# Presidentwe
# avideo
# specieswide
# conferencingnevertheless
# youof
# illude
# citizensinfor
# drivew
# qualtiy
# reviewsopinions
# outbreaking
# cehicle
# sucome
# manange
# semisupportive
# origanal
# Lukewatchman
# recapaliation
# shadowss
# saysA
# responisblity
# Furhermore
# thift
# undernearth
# AWALK
# sharkssquidoctopiand
# agencyReuters
# wrriten
# Democrars
# punnishment
# confidense
# marsians
# tofor
# youYou
# jeopardises
# curioisty
# AFCCIO
# eger
# sonds
# 5minute
# Eletroral
# tyhan
# Venustravel
# Thisprocess
# stresss
# airyour
# theough
# Electrolar
# remainsscientist
# dissengaged
# signifagance
# deviding
# planetEvening
# eelectoral
# April5
# electrorial
# worldvaubangermany
# cantidates
# imagineand
# riverMeaning
# sutdent
# intreasted
# expriments
# Venusis
# contridiction
# carowning
# cleand
# Planetery
# assuringly
# alerady
# Ialso
# expesilly
# togeher
# helpmakes
# actbuy
# famles
# represnted
# ouself
# waight
# properley
# Rixhard
# differernt
# whereshut
# movivates
# ingnoring
# MGSarrived
# 501
# nedded
# sialing
# varietys
# countiing
# Smartroad
# accutally
# citizenswe
# representitves
# nightsky
# deosnt
# presidant
# prattime
# bullyed
# oncer
# veinece
# peoplee
# lifeeffecting
# pannic
# aloso
# confroble
# crusial
# Clolombia
# datted
# twoas
# shouldÃÂt
# seveteen
# torward
# indrectly
# onedimensional
# inconvienance
# development2
# teachersa
# statesBut
# smartjust
# stpo
# vibarte
# healthand
# terrene
# workbecause
# byebye
# coprorations
# Natrual
# sruff
# becaomes
# irrationalPlumer
# studentsbecause
# schoolthis
# runningstamina
# Legislautures
# implemenet
# supporte
# electrocal
# Automoblie
# afordable
# easie
# tinglying
# hundrendthousand
# 91
# pensil
# averadge
# intsinct
# degressliquefy
# peove
# landforce
# 802
# laggugis
# extemsive
# oneprofessional
# relavents
# Especually
# spans156
# that70
# sirfaceparagraph
# herbecause
# Seconddirveless
# dangruse
# 2035
# malunfunctions
# pmanet
# oxugine
# counntry
# looklike
# toobecuase
# hthat
# esoteded
# Drousy
# Earthslike
# jobthing
# osmeones
# caraccidentcaselaw
# studentplanned
# regluar
# presidentparagraph
# cloundfraped
# FirstDr
# accindent
# planprocedure
# equipted
# passengerthe
# evolted
# fahrenheite
# alterning
# constiton
# Sometimethe
# scientifcally
# classroomand
# whttling
# orgtextinganddriving
# ussage
# couontry
# thatÂs
# plannig
# MrSenetor
# iSTEP
# magizines
# statemnt
# magnifcent
# Lerning
# acandidate
# interging
# casusing
# asfencing
# represenitives
# leavels
# usuing
# metrorails
# couldnÃÂt
# chatches
# decised
# winnertakeakk
# elliminate
# BESTLAID
# 794
# nonintrested
# bordersRosenthal
# rightthe
# systeam
# makeis
# apporopriations
# realitly
# dinneror
# selfdiscovery
# assocaiated
# pressire
# seamans
# licenesed
# resticts
# atomatic
# conditition
# afarid
# plaese
# facinationg
# siduation
# displaied
# destenation
# longtern
# 152
# highwayIf
# sflashing
# resimbled
# facilityto
# Probaly
# Imagaine
# vitial
# explaings
# prefeence
# baseballvolleyball
# coampaign
# vechicule
# immisions
# flot
# Vinece
# masterpeice
# roilng
# systemtheres
# edusiowfa1520151204whyisourgenerationsattentionspansoshort
# cheerfuly
# fuek
# somewhereor
# scientistsresearchers
# defences
# nonlazy
# technally
# benitfical
# elatronics
# becausethen
# jubget
# investgion
# anables
# landforn
# technogy
# differentwhich
# clonclusion
# slaters
# visists
# electionrequires
# flexibleand
# 999
# studymeaning
# dessided
# sensros
# examplestudents
# canadd
# Gorereceived
# youngcows
# yearbooklearning
# breathinglung
# consiracy
# ninteen
# biuld
# complicatedbut
# mystrious
# Pharagraph
# senser
# futurtistic
# theryre
# irrationalthese
# expesive
# disvalued
# atoumating
# deepdown
# stressfulsometimes
# porblems
# systemin
# throughing
# abudantly
# enteresting
# mecanichle
# busey
# expanced
# ultimently
# whittiling
# phonessmartphones
# milefuntion
# distroit
# misjudgement
# Nextaliens
# benift
# productiveparagraph
# aprtial
# hereMom
# headantenasbodyand
# wwork
# advancment
# representaion
# potenBally
# comaarpcarinsurancehowcarinsuranceworks
# efficienty
# puing
# outcomesÃÂ
# motorSource
# easebut
# hekps
# simmularities
# inmportant
# biais
# acloundless
# rebundal
# pollutionpassenger
# survies
# OPIONE
# Contitstution
# workmuch
# alltheres
# examlpe
# limliting
# patricks
# dioxcide
# SSCharels
# Oconners
# indcidents
# Reaseachers
# parisfrance
# prosperic
# voteso
# outiside
# emoions
# subjuect
# seventeeen
# insentives
# citystreet
# nessesarily
# powerul
# angerly
# accepters
# friendfamily
# hightraffic
# accendents
# dramadically
# 3003000
# orgtemplatesstorystory
# endedparagraph
# liqufy
# deppest
# youer
# sopulled
# satisfacion
# considring
# COMPAIN
# proficent
# teensfriends
# sterio
# apose
# oppsoing
# friendsfamilyetc
# systemwhich
# intirested
# aguments
# actses
# Donheres
# neighbouring
# emissioms
# anmateur
# miserbale
# terrestrail
# studeis
# dangeruos
# prepair
# diffrenece
# vheecks
# gamesdownloading
# commuit
# cloest
# naton
# dissagrees
# happysadmadetc
# 250
# dioxideclouds
# consequetively
# issuesroad
# Paragraghs
# iligal
# cosing
# Bogato
# comeAlso
# perductive
# whise
# 700pm
# recongnized
# occean
# tellwhere
# feell
# esssays
# vidoeography
# disreguard
# reasond
# controlable
# asdding
# enivornmentally
# interpate
# personafter
# clsoer
# reliese
# forcefeeding
# greatIm
# dongo
# onelike
# talksocialized
# capibility
# certant
# workng
# megalodons
# mallks
# FirstProfessor
# phoneyou
# wholey
# leadit
# dermocratic
# standerized
# ineed
# Classroms
# didate
# techsavvy
# disaventage
# Intelegent
# loosin
# opionon
# homeif
# descrinbing
# perhappes
# guarunteed
# itts
# eaisily
# illution
# trappen
# conveniencelike
# auter
# disguist
# studinng
# highwayRosenthal
# marjor
# semiautonymous
# californiagiven
# pyramidlike
# undertiminable
# similaraties
# Posner19
# mantains
# anmials
# ajestments
# 434
# whoom
# staisfaction
# 3045
# becoma
# carlimited
# Venuns
# thousinds
# emotitons
# govorment
# gradesand
# Presidentcause
# camra
# runshard
# gworing
# infromationadvices
# rrather
# clothesshoes
# mazimum
# notsosmart
# carentertainment
# HitandRuns
# unresponsibl
# liabilitt
# windsand
# comparson
# annoced
# 40million
# invalueable
# othersWhich
# obstinant
# angryDAlto
# exeeds
# thounsands
# realise
# Fortuatntly
# wmaking
# passengars
# resluts
# misisng
# teenssafe
# someine
# represenitive
# combersome
# subjust
# waterbales
# Beyon
# protoction
# aiplanes
# ConclusionThe
# perdictions
# vertauily
# arouhd
# gratful
# automile
# privaledge
# Adivor
# withmy
# concissed
# astronomoers
# unerstand
# asPublic
# theycould
# pollutied
# gron
# coputers
# preassureheat
# arrieved
# viking1
# Ellectoral
# elctionselectors
# 134
# rivale
# sterr
# monitorization
# thust
# oribicularis
# accursy
# realse
# Perment
# tehnically
# Attening
# teachersdesigned
# couldny
# reopresents
# oont
# saftely
# substand
# workclasses
# picures
# soomething
# preferr
# 3phargraph
# castThis
# ENVIRMOENTAL
# remainings
# votesRichard
# dissaper
# fifteendollar
# theelectors
# exsiqsitict
# Firstthese
# thuings
# saysthousands
# recognise
# govornments
# deesigned
# theink
# problemwalk
# catlle
# seemable
# NASAS
# Representativeswhere
# personper
# problemand
# notifiedtherefore
# teachersand
# FREIBURGNEAR
# timemy
# challengesparagraph
# cleannig
# elace
# dirveless
# prioritised
# 2000but
# audomadicly
# erll
# directionif
# counterfits
# istant
# requiresParagraph
# populrity
# muich
# 450
# consitering
# topicsIf
# elligable
# depised
# experiencethe
# 90180
# thoughroughly
# endorphines
# fahrenheitm
# April1998
# previleges
# withtecnology
# studydespite
# SCP2317
# bisnesses
# mAKES
# pollutionThese
# wellworth
# confortble
# faceThis
# 271
# schoolsickly
# semisautonomous
# humens
# 7079
# superstions
# temputure
# technoly
# astronomos
# winnerPosner
# proffetionaly
# nigthtmare
# tournamentsfencingboxingreadingwhittlingand
# wjat
# vidoeo
# universitybecasuse
# answersresponses
# conutry
# possiblelity
# precentages
# benefitfrom
# through12
# constuctive
# citiesThe
# phonemobile
# creatuve
# democarts
# supplys
# assuptions
# 2018
# countercaims
# moreequally
# 1945
# Senors
# allopw
# DEARstate
# pollutiongreenhouse
# navagating
# hewent
# UNmasking
# indepedantly
# acceleratesteerand
# staris
# fulltimes
# Scientest
# fruadery
# meanto
# fladed
# Quizlet
# leavel
# Facebut
# pieace
# 6rd
# anachronismPosnerParagraph15
# peirod
# canddidate
# dily
# votingbut
# teacherprojects
# Eletronical
# attuide
# movineon
# onlining
# Conclusionin
# commutate
# smilesworryor
# oxygenfoodwater
# bicked
# legislatiors
# carbanning
# stellers
# determide
# Afterthey
# reposiblilty
# assumimg
# importantanother
# inclinded
# presidentail
# sevenyearold
# inspried
# govbriefingroomnhtsasurveyfinds660000driversusingcellphonesormanipulatingelectronicdevices
# FACD
# convined
# benifity
# orgainze
# earthqaukes
# Thease
# mesasmesalandforms
# techniquesskills
# beggening
# sailong
# resepect
# eraly
# overcomed
# somedys
# overbreak
# experiances
# ifthat
# thenthis
# electorak
# tranmit
# extermly
# decicion
# poiliticans
# taolpopes
# maintnence
# somwthing
# majoratiy
# thaks
# callibrating
# maunfactures
# Aftrer
# underwelming
# warbut
# experimet
# schudule
# electe
# novemeber
# imagintion
# cartages
# ahrder
# expalnation
# workhomework
# Heridrun
# technonology
# Idefensible
# Venuslike
# probility
# tryoutplay
# plaents
# Instagraminstagram
# tould
# distrubed
# manucturers
# tquestion
# opionio
# 1995Source
# worthyly
# thist
# differentlywhether
# findind
# etransportation
# 2221
# Floridads
# becasues
# elementray
# sucides
# atenttion
# foursentence
# Carolinavoters
# difficulit
# Hve
# awiel
# participtate
# depleat
# aduts
# placesand
# bythemsevs
# knowleage
# traval
# 1internet
# evironmwnt
# ususe
# payclose
# opportunityexperience
# chaging
# quetions
# Vaubaun
# understandment
# fatehrs
# technologyworkingplanning
# ruiened
# equiopment
# creatinf
# repeatingly
# cancellationsfor
# companines
# authore
# reulted
# efeil
# skyhow
# 2443000
# Miachel
# percentigs
# partydominated
# wonderingdo
# nobdy
# cetainty
# teacherdesdigned
# recgonition
# boredThis
# advantagenow
# 75or
# beas
# artile
# restauran
# jumpingthat
# intesting
# amire
# AdministrationWhere
# eitheir
# afread
# crashesand
# Modent
# 9296
# champaigning
# experesions
# needstudents
# siht
# FAcial
# unnessacarily
# coinencidently
# wholistically
# clasrooms
# tostey
# electorsPosner1
# twinhow
# WestsThats
# Vicking
# 40000along
# genaration
# segregationistsmeaning
# pricees
# accessand
# elctronic
# gavie
# mushroomswill
# Emplementing
# corrisponding
# advicethey
# offchance
# historyThe
# particiapate
# howeveer
# Aciton
# hungery
# intelegent
# drescribe
# carbride
# electionthey
# industies
# confiused
# filmsappeared
# recignition
# chaso
# coanidate
# dicisions
# plumitted
# Earthpara3
# elelctors
# numder
# baned
# knowlwdge
# allwe
# gargantuous
# uncontrolbaly
# hospitaland
# Studentmade
# stroger
# electorswho
# cerfiu
# Zygomatic
# ecpressions
# Suberb
# fariheit
# resipes
# staudent
# leastly
# tincan
# 2021
# bennefit
# intesifying
# electionvoters
# Consistution
# infomaion
# itÃÂs
# antolock
# thck
# regionsouth
# subatle
# restaurantsso
# inflorme
# eyetoeye
# poinless
# 18931900
# lowmiddle
# electircity
# foalt
# landinf
# malfucntions
# onhalf
# regoinal
# contagest
# shoulndt
# sercets
# closesy
# beatutfil
# studentstudent
# differrnt
# peruit
# passivly
# becaome
# thinnnk
# Finnalythats
# pshysical
# collectivley
# practial
# srticle
# diastor
# BogotaParisand
# differenty
# personalinjurysandiego
# convine
# everyhing
# saferbetter
# sersiously
# coincidentall
# sometype
# polluition
# meanwell
# envoirnment
# beniftial
# embarresed
# beneficialharder
# forpresident
# wellwishing
# Flexiblity
# buisnessman
# palces
# Theere
# santes
# destrution
# electorss
# noGeneric_Name
# becomoe
# driveroperated
# evennumered
# indeeds
# candidatethere
# spicific
# percoent
# carshop
# sudenta
# worthing
# proprotional
# disition
# detailedon
# envent
# goodnis
# approvedd
# decisionthe
# tigth
# sdrivers
# rectangularsquare
# Europethe
# aritcles
# helpout
# Democrac
# studentsand
# munny
# 39
# myselfI
# liablities
# scholled
# cowyboys
# avioded
# safly
# selfreliance
# oopose
# whilr
# famiies
# gonverment
# anchronism
# counselers
# shouw
# preassure
# motherfather
# Therehave
# adiquite
# wereparagraph
# acompish
# pappers
# movents
# myslf
# aboliashed
# Finallyyoull
# resonas
# placeyou
# fortythree
# NonAthlete
# satae
# Apparenlty
# holltwood
# desaters
# 3also
# corrosvie
# ideainvention
# pershaps
# coastly
# evinsions
# uturn
# Computerdriven
# ploicy
# lissend
# htye
# cerent
# wintakeall
# uneccesary
# obstical
# pivked
# posotive
# listining
# caude
# articraft
# usespecially
# daypg
# sturctue
# oinions
# mthod
# siblimal
# workdont
# upstet
# observationbecause
# erotion
# 1900s
# Operandae
# carryint
# cityair
# worseConsider
# surfaceParagraph
# 5500
# sentens
# sophisicated
# ancietn
# moreand
# Astonomers
# recoginze
# copasity
# distarction
# abaut
# wisley
# Aeronaautics
# artclub
# ebonyhaired
# eduacation
# illinosworking
# needsAnd
# tooparagraph
# pasaage
# lifeunlike
# sadband
# reducion
# Thatfor
# woithout
# paragrafh
# convinet
# sytyem
# badd
# orgteencrashriskspreventiondrivingcellphones
# 00000001
# passageThe
# topuch
# emotionshappinesssurpriseangerdisgustfear
# acyually
# rushhours
# eitherway
# comfused
# daughterson
# extracredit
# ofgreenhouse
# nomie
# explainingand
# inconcideration
# maufacturers
# emotionsThis
# defanitly
# classroomss
# Plumerss
# technologysafety
# footballsoccerbasketball
# tcars
# posner
# sayhey
# Emisions
# waysaid
# FinallyGarvin
# thisthat
# exersice
# emmiting
# traffit
# wwhen
# interfear
# experinece
# paragrath
# usstudents
# countryits
# mathscience
# Fahrenheit5
# developin
# componenet
# choiceAnd
# instructorThis
# fowrward
# pradictable
# Rehibilitation
# overwhemled
# aacap
# electios
# phycologist
# orgcronews200907shouldcellphoneusebydriversbeillegali
# opperating
# NevadaFlordia
# teachesr
# historymath
# moajoraty
# theorys
# com201804howmanycaraccidentsarecausedbycellphones
# Nixton
# carear
# emotionrecognition
# describles
# avoice
# teendriving
# frightenning
# identfies
# nakes
# Outsideofthehouse
# GalaxyMilky
# pariticipation
# emontions
# tpld
# bluring
# wouuld
# excitning
# conculation
# foccusing
# twosecond
# expeince
# Illonois
# atrounauts
# desnigned
# teacherdesign
# disover
# congree
# discusted
# wicgh
# veiwing
# phiscal
# alleven
# yarsa
# citiescali
# watchplay
# Columbai
# realixe
# canels
# awille
# Venusd
# echallenging
# skateor
# futue
# bedon
# laving
# ofcorse
# swingstate
# elcators
# dtiiri_gif
# forver
# sitiouions
# possiblefor
# o9en
# stateit
# twoards
# cintribute
# funfree
# vacaison
# postionestimating
# Onther
# constantily
# Apperently
# opcion
# scarybad
# cowa
# Mcgriddles
# memorise
# Reguardless
# shrieksWell
# stted
# achient
# concern8
# eathquakes
# voulintary
# mercedesbenzaudi
# extraculirrclar
# ctopped
# jobas
# tournamentsfencingboxingreadingeven
# 1000000
# foced
# expireneces
# averagof
# presidenti
# elaborationg
# peerson
# inderstand
# portraies
# niot
# 2836847
# increaing
# instctors
# Aacap
# nessity
# startstop
# ciricullar
# Pradford
# advanges
# artifactsreally
# mindaltering
# dangerof
# belivers
# wrec
# 871
# 16times
# torwds
# freiburd
# bazzar
# rador
# currantly
# oppertuntires
# cientifics
# swiches
# 14million
# littly
# commutin
# hpot
# slenderman
# elctos
# safetywise
# electionof
# nessesites
# disaplen
# ferhight
# twords
# advce
# candidites
# presidentvote
# oppoortunity
# endeavorsP8
# terrians
# assumpution
# regnize
# 60s
# FranceGermanyand
# votesis
# inconvient
# altimately
# goesminto
# comperhanded
# disspear
# adviceyoull
# tranregional
# accedice
# teachersguidance
# envirement
# wristsbands
# knowledgeful
# NaBonal
# ypou
# countriescities
# smartwatch
# thatSome
# caN
# hardeset
# incates
# saft
# imagtheant
# occasinally
# happymadsad
# expaining
# expressionwas
# oppsing
# goodBecause
# astronuats
# binifit
# tamperd
# unnecissariy
# Nothey
# bysometimes
# eripting
# valcano
# questionand
# sujest
# advanage
# sitautions
# gicing
# repersentatives
# importantuseful
# vechle
# vecheil
# Chinia
# timerestriction
# dislexya
# opppesed
# tmeperatures
# drivewats
# citizensstated
# willgo
# ofcurs
# TransRegional
# SystemFARS
# everythingthey
# announcded
# COULDVE
# unhealthyunnatural
# oppuritnty
# comsafedrivinglikelihoodofcrashingwhiledistracted
# 22euros
# drivnig
# smartwatches
# crub
# popularf
# levittown
# 2739
# expiernces
# somehere
# poinmts
# summorize
# timeSource
# erins
# lessonsAnd
# curuose
# Feriburg
# habbitable
# expensivebut
# zygomtic
# 971
# tenseIm
# delarships
# playerand
# montain
# disapate
# txtin
# fine31The
# unmanagable
# posple
# civilazations
# windsheild
# technologicallydependent
# prementioned
# isty
# Bmes
# borred
# statest
# peoplemostly
# mght
# programmes
# learningGeneric_Name
# palnning
# DSlto
# accces
# creativelearning
# limations
# highlyregulated
# silmilarity
# intermet
# studant
# sunThe
# identicle
# ReutersDuffer16
# oberate
# aggitating
# distractedas
# temperatur
# hummans
# microgrmas
# adolesance
# spoted
# alows
# econiomic
# Mkaing
# candident
# Goodmoring
# stayong
# EuropeGreeceand
# ault
# descorvies
# loveing
# smogwhich
# camaign
# dearful
# qwell
# Francenamed
# textMeanwhile
# havw
# partnernign
# unefficient
# germeny
# FromPROPER_NAME
# festvities
# 20s
# fatalityfree
# electoin
# tableennis
# terrable
# bettre
# walletpurse
# importantlearn
# furtherly
# outcmomes
# vincis
# confusef
# enouf
# evne
# driverin
# useother
# abanding
# timeseven
# infromed
# overwhellmed
# tragicic
# tailpipesAfter
# besfriend
# unman
# 11
# benifites
# questionbut
# mostrocity
# negitvies
# indesirable
# authorIt
# sovling
# jugdemental
# soport
# thoughtsyou
# selfsustaining
# homeFirst
# extracrrualar
# and
# Haunght
# problaly
# senetor
# CydoniaIn
# cnandidate
# personoption
# leason
# vapes
# hihgways
# ofALOT
# exctracurricular
# trueIts
# garge
# whothout
# Atfer
# oneone
# conmftrable
# reaeon
# repairand
# volcanoespowerful
# statefunded
# responiblity
# about4000
# personl
# leeps
# devic
# conditionsbut
# xample
# toparagraph
# selectingthe
# atomshere
# antentionand
# opprotunitys
# analyazed
# 1639
# parkng
# viber
# tennisand
# Factial
# presidnetal
# volleyballsome
# intentful
# teacherthe
# eliminaed
# presidants
# persentages
# actirity
# choiceto
# exensive
# nonververbal
# themselfes
# intorested
# VIOLATORS
# sytstem
# veans
# stopgo
# theybhavent
# highten
# garduate
# adavntage
# dollarsThere
# humam
# crashesaccidents
# knowledgement
# reblock
# friendsschools
# initimidating
# responsibiliy
# STATEHAS
# atomsopher
# intructions
# locationsthe
# Coyboy
# Autisum
# qutie
# measurments
# shipes
# resembales
# Marsour
# comerce
# covince
# perpares
# opotion
# noreduced
# studentphoneand
# unforunately
# 1319
# steeraccelerate
# centersalso
# 1700
# horrble
# defenitly
# benchs
# themmaking
# diliver
# dangerousehot
# garente
# adavancing
# craked
# learnand
# manuftor
# emploees
# 2031
# studentcentered
# schoolÃÂs
# winningsource
# emmison
# coumputer
# celebritu
# httpswww
# compainies
# startedGeneric_Name
# transportataion
# couldnt7
# presidentThats
# polpulation
# yaaaaaa
# sililar
# moter
# dictector
# detromental
# illustratesOn
# symotainiously
# dioxideand
# eliviate
# Conclusionevery
# HYBRIDSAND
# indivaduals
# Alast
# Responsability
# sicknessor
# iyou
# reasourses
# meteroids
# unbeleiveable
# piolet
# 10When
# preventng
# 2Venus
# lisnces
# derivers
# ingaed
# corect
# slite
# obiting
# familyhome
# Valledupr
# precambrian
# hevily
# coviering
# ubers
# presrving
# airr
# 45000
# orgusfacts11
# trafficless
# crativity
# roff
# activitylets
# regarless
# atetion
# himselfWhat
# neighborhoodsaid
# talkwalk
# risouris
# smartter
# beaues
# micograms
# 401
# nution
# ventage
# lowesteemed
# himshe
# creaper
# oftenly
# luarn
# datails
# facila
# schud
# Safetey
# wouldsay
# auothor
# aarons
# plateu
# firie
# constist
# falce
# wouldknow
# banifits
# mkae
# easlily
# iding
# awayand
# peopletalking
# tretmeant
# occouins
# doinga
# Fahrenteit
# faceaccording
# tobut
# newbut
# CarterBob
# descoverage
# orgdistracteddrivingresearchnhtsadistracteddrivingcrashescost
# whitteling
# understading
# edjicated
# distamce
# 1968
# dontof
# fingure
# actiivitys
# Colloge
# Eveything
# technoligy
# teachingthe
# Metinguey
# lowerd
# desiceing
# untimidating
# incredbly
# multilayed
# getteing
# fullyfunctioning
# cludy
# makeand
# woudlnt
# vocationaltrade
# wiel
# 730am
# aplanetary
# ovwer
# differenes
# unmannedsince
# needand
# safetycritical
# Overrall
# Italya
# outofthisworld
# binfit
# marsThe
# wisitersfor
# pollutionsource
# hobbys
# mitake
# intendedvto
# optamistic
# brieflty
# slolar
# GorePosner
# electal
# hihg
# nothigbut
# arounced
# Basicaly
# rquired
# Senitors
# benfital
# recoreted
# wasnt
# lessonbecause
# reasonskeeps
# enthuriastic
# candidaate
# emotionrecognized
# continuisly
# provdided
# velleys
# displeas
# secund
# Columbiaall
# nautre
# brightrst
# towrdes
# problom
# comcaraccidentcauseofaccidentcellphonestatistics
# presidentThe
# toutering
# representavite
# friendswill
# inhanced
# pedistrian
# suburbuan
# stuffso
# stricted
# undrestand
# 3000
# adviceopinion
# coustomer
# brige
# havents
# tranportations
# traffle
# Teaxs
# Geoerge
# advanved
# supprts
# constructa
# crucal
# thehartford
# sneakersrunning
# encouunter
# yearor
# lugg
# regareded
# Althogh
# 797
# wothout
# secondthird
# Legistature
# pench
# bulliedover
# archieves
# electronicaly
# jrunk
# ThereforeOnline
# worldpara
# evedice
# saysAs
# stressrelief
# soso
# forcng
# ressolve
# surprisedisgustfear
# deges
# balive
# votesPosner
# alleins
# Assosiation
# footprintshmm
# campaignto
# plave
# themsource
# prramids
# stressul
# decidethe
# paintersdrawers
# indecate
# overruledsource
# eleteric
# eatern
# techerdesigned
# leadingtrackvolleyballgolfingand
# scaredand
# noumerous
# jobsfamily
# minite
# vandalisim
# chalanges
# siteseeing
# Cowboysaid
# effectivley
# fauld
# imorving
# becues
# underachievingso
# distancesforms
# blamn
# emmensely
# surfacelasted
# cattleboater
# Sometimestheir
# battlecompete
# innovatiobn
# 12
# stuuf
# wheil
# Gorewon
# GlobalSurveyor
# Manypeople
# sympthatic
# acceptince
# reconition
# teachimprove
# Reisthe
# worksstriving
# grocures
# otyher
# projectsshould
# correcthow
# dixide
# eathquak
# apportunities
# troble
# 20So
# tooThis
# differient
# comcaraccidentcauseofaccidentcellphone
# kenndy
# wesites
# DOn
# unprepare
# empahty
# teacherss
# lowerincome
# shyrocketing
# aplogize
# aultications
# comparrison
# amking
# Firstmost
# pargrraph
# aftward
# electoralvote
# adaptablity
# Peole
# crosss
# sayingI
# lader
# Indefense
# dontbut
# irresponsibles
# betrayedhowever
# skymaking
# democrticin
# prsident
# testshomework
# mras
# impartante
# boatsand
# manufacturerer
# manufature
# caron
# veanus
# anymoreand
# recgnize
# hapynessdisgust
# ansers
# realese
# sunBeyond
# 242011
# voluntiers
# commiteeand
# Westparagraph
# invlove
# famalies
# motherbut
# threemillion
# dbe
# sdend
# politicains
# endbeavors
# abive
# allI
# daythe
# counteries
# computerassisted
# diocide
# reasource
# spieces
# Firstlystudents
# saidOur
# pariceipate
# electorol
# NASAHas
# calssse
# rasises
# selftaught
# parkLarge
# overuled
# assisit
# knownledgebut
# Furthermorein
# candidateThis
# paert
# outDont
# hert
# onlinealternate
# Turely
# simplilar
# innormality
# schealue
# himselfhe
# realtion
# choicesdesicionsThere
# transappeal
# harazardous
# pesidentbut
# arrnes
# acccelerate
# planetit
# opinino
# Eaths
# buisneses
# systemvoters
# unfilmualr
# nautural
# oppsion
# sstudennt
# teacherassignment
# ferther
# surroning
# thatr
# equimpment
# trnsregion
# obilatgated
# conving
# decisicions
# releaves
# chnge
# fator
# postitives
# assingned
# somethung
# acceident
# condititons
# helpor
# reproccutions
# greenpurpleor
# monumet
# nowhold
# endarging
# enfourced
# ticketscourt
# fouced
# dontcare
# choicesfor
# brightestv
# avaliabe
# answerperspective
# cumilative
# progressivly
# simething
# transfromed
# MarsEarth
# generallly
# laborous
# appreaite
# autrocities
# beive
# fantisized
# ThereÃÂs
# 1945world
# computerthis
# schook
# fahrenhait
# difeferent
# knowbut
# meteral
# confusionboredomsadness
# carebut
# spurise
# Eaqrths
# demostrating
# professormof
# communicationwhich
# Limitng
# ecspecially
# plalnet
# flahy
# archane
# wwant
# dramait
# devoloping
# sociteys
# therelike
# freeminded
# overlookd
# lifethis
# discharfed
# featureslike
# Hawever
# artices
# followinf
# arplanes
# conferening
# youas
# suspious
# inpacted
# reseaching
# Hartfor
# Fahreanheit
# seafer
# inaccutartly
# comared
# Souce
# porving
# adamatically
# comfertoble
# Ultimatley
# thenand
# froever
# deicranditate
# tenty
# studend
# runers
# intrestred
# countryonly
# acciedent
# somoene
# ethier
# unintellegent
# Brussls
# featchers
# expample
# apealing
# welloff
# convienently
# ownershipper
# hydroplanning
# unperdicable
# boughtafter
# plentifuland
# earlierand
# RELATIVE_NAMEs
# constituition
# 2573
# wrongwhich
# somehing
# consruction
# listengive
# uinlike
# presidency9
# selfsupervised
# landorrms
# seeJim
# chamges
# forwads
# meor
# isas
# sopport
# AlGoreThanks
# expidition
# EarthA
# dect
# footballsoccer
# othercowboys
# benenficial
# 1988
# dirction
# Scientests
# mphdriverless
# responsiblitly
# Finantially
# dsent
# happs
# vehice
# succesul
# cway
# princlai
# conclusionwe
# probrobly
# arumentative
# extermely
# tomorrowHe
# vaulse
# sitseeing
# tlike
# paitcene
# idntify
# thsn
# manufacturures
# comhowtextinganddrivingpushinsuranceratesup4163808
# coopperate
# processthey
# techoology
# succeedhome
# implacations
# numerouse
# theripist
# 1980s
# theopposing
# extracular
# protechnology
# undestartand
# pagraph
# timemanagement
# paciest
# carsowned
# polutionand
# presedency
# asumed
# lisecen
# illisuin
# pivking
# explanes
# falllate
# freasher
# lurn
# blammed
# oddjobs
# 660000
# SecondIt
# classse
# eqaul
# landformations
# stateswhen
# votefor
# pedeastrians
# befiting
# reprensentatives
# wasequal
# happyworriedsadetc
# handhow
# relibale
# Lawmarkers
# CretePanama
# theyÃÂll
# disspose
# petrolium
# carsized
# happyto
# 30and
# thatThe
# psycholgists
# emmtions
# competting
# fanticize
# ruckess
# drivrless
# Horts
# enviormentally
# distracBons
# SurburbLife
# intereststudents
# NHTSAcom
# legislatur
# prblems
# fencingboxingreadingvollyball
# expriment
# suden
# 22211
# cuntrys
# homehe
# epidemc
# filfty
# standerd
# refreshmentof
# friendsmake
# truble
# nesscities
# Vienceand
# gondula
# SEBE
# captio
# hpe
# proventing
# Dugles
# courtcase
# vistits
# apprieciation
# knowledable
# recivies
# multipal
# BECUAES
# destroid
# consitions
# manufacturues
# officerss
# acadimliy
# commmunities
# whileworking
# therere
# arenon
# manufactureing
# DAltos
# adavntages
# moing
# limmitted
# compeling
# forsome
# excpiorience
# Familys
# BÃÂs
# parished
# wordstake
# diffict
# recless
# Huange
# indesicive
# bankruped
# evrywhere
# someoen
# Withought
# arguemtn
# consedering
# detecing
# vraked
# systempresidential
# celbrity
# electronies
# anylise
# extraculiclar
# Scine
# Secondlytraveling
# reist
# avanture
# studnt
# interstead
# deoxide
# couid
# 22511
# boikes
# envirionment
# familyfriends
# zonesetc
# statea
# 1017
# benefis
# otherr
# represintives
# cilmate
# electrols
# Sciencetist
# rocksgasor
# beening
# deomcorcy
# unmaned
# CALCUATE
# triedandtrue
# guarntee
# shoukd
# incffecient
# rurope
# learnmng
# conusion
# citesens
# brightes
# WALLE
# licentce
# warmwer
# diffenrent
# sponantiously
# Skandians
# Vurbans
# compilcated
# oneIn
# dillemas
# evveryone
# DIESELS
# anyreason
# onanother
# disatisfy
# Eviromental
# percieving
# annocunced
# whant
# doingthey
# mountins
# vrey
# blindhandicap
# cerfui
# 636000
# wellconnected
# carspeople
# extroudanary
# YouTubeand
# dicovories
# irrritated
# springsummer
# stairing
# occens
# societty
# timethe
# predeterminated
# relativesand
# salf
# sporthobby
# largerst
# giberish
# RunOffs
# summarise
# citizensyou
# electionsThe
# outofcontroll
# goodtalented
# doolars
# mystircal
# Onlineclasses
# pklates
# xent
# decisson
# currenetly
# opinoin
# inevidable
# gardians
# noify
# statesLuke
# diffeent
# citics
# 1978
# plentifull
# Howeverthe
# breakstop
# humansand
# redecide
# presentsbut
# onehundred
# wraming
# madee
# obselite
# intails
# certainy
# AmericaRosenthal
# passagethis
# pesure
# nworking
# Envionmental
# bussinessses
# wasonce
# acertainments
# futurebut
# onnes
# atrifact
# thatpeople
# eaither
# Compuer
# padestrians
# persection
# practicle
# frieds
# fihure
# bikesSelsky
# dier
# involeve
# potentail
# expenisve
# ThemeGrill
# qustions
# sensable
# schoolhomeworkor
# ciztens
# concludsion
# peoplw
# misunderstading
# lighs
# viewyou
# 70kg
# Feul
# dayevery
# wisdomseeker
# pharoh
# disections
# deceving
# Trebuchets
# germanybut
# episdemic
# oppourtunties
# reeeeeeeeeeeeall
# mystereous
# Sacandly
# exericse
# voteThen
# Woudnt
# Represenitives
# streest
# thinkiing
# votingPoshner
# bulllying
# resliency
# boyfriendgirlfriend
# Excersize
# DAlto
# extracredits
# automoile
# colles
# igot
# viewMalins
# sametimes
# opianion
# hopelessand
# genrell
# arguent
# thefeel
# weels
# Finially
# diffcault
# problembut
# articleDriverless
# inhospitablescientist
# adevnture
# sufering
# havor
# teired
# combloginsurancehowmuchcarinsurancequotesriseafteran
# sapcecraft
# emergencys
# 2when
# 1320
# citizensThere
# eclass
# diect
# buisy
# nearrecod
# mirrow
# thtats
# computres
# EMAIL_NAME
# winnertakes
# planetswhich
# pasion
# in1968
# suggestings
# agees
# dicouraging
# driverles
# imbarest
# whithout
# perferd
# dtop
# Thirdyou
# gliches
# myterious
# arugue
# unlikelyconsider
# legislatrors
# statedGoogle
# servrice
# unsupected
# Indefensibel
# airgasSometimes
# extraterestial
# Greecewith
# affectall
# mager
# facinate
# shopuld
# rocksThe
# 220
# knwos
# negeitive
# benifts
# extroardinary
# edivice
# 425
# accualy
# helpthen
# counterty
# mechnal
# saysBy
# carryfully
# dmvcheatsheets
# Bomder
# thoughit
# 1because
# planetray
# ph20
# trecharous
# Multple
# presindential
# dissapered
# 513
# thirve
# controlThey
# sencers
# WinnerTakeAll
# qwant
# sempathy
# coould
# princeipal
# mounument
# atmophere
# receal
# conscidered
# auntomakers
# corrasive
# frequen
# determened
# riskand
# wjy
# paperit
# savge
# accasional
# satelittes
# corears
# 10am
# suppliesanimals
# atmosphear
# sedment
# studients
# colleged
# tradect
# elertoral
# Studentsspecifically
# deathes
# 215
# feautire
# rockrocks
# corrods
# chromebooks
# depeneding
# subbjects
# enquitment
# independly
# collegewon
# CaliforniaNevada
# caluculation
# Wensdays
# gaing
# excist
# diiferent
# reasonnings
# costefficient
# Variouse
# SOLÃÂS
# cpouse
# appications
# atmospheris
# homedistance
# eventrally
# floow
# cogelle
# Imagain
# intions
# FACSs
# announceed
# matbe
# makingprototyping
# resoluton
# charityatrisk
# atmospehere
# posssibly
# advicemore
# stof
# Aparrently
# 2935
# scense
# 55000
# looksv
# hundredthirty
# eviornment
# Cerificate
# toneYou
# evidenve
# paragh
# englishor
# greter
# taxesno
# imagion
# Chellenger
# platent
# Teacherdesgined
# hving
# 2000he
# resourcesfinding
# worldCold
# Paragragh
# accordingley
# hudge
# potentually
# coincedince
# uniteresting
# Culombia
# KhanAcademy
# diffirences
# fromBut
# sureface
# articall
# slididng
# manyh
# edunuity
# commuinicate
# foodwateretcand
# calledexcuses
# fahrenheitans
# animials
# effictive
# doingtrusting
# peopson
# verhicles
# April51998Mars
# frontails
# GirlBoy
# suupport
# jobvolunteere
# noly
# eveyrhting
# notfy
# hasatax
# howed
# effectivally
# possiblby
# yhat
# Prtection
# implomented
# determinds
# nighbors
# Beause
# lessed
# feelong
# landd
# prooven
# congradulated
# deveolpement
# hogh
# Egpytian
# safetyness
# movementschanges
# Adveanced
# cfocused
# ...
# threy
# designsheadlinesand
# opinionand
# necesitiates
# vater
# researchfind
# bvest
# environmet
# behide
# itandor
# fobidden
# discovert
# enything
# Unrealted
# readingand
# noneducated
# 5000000
# inperson
# emotionsPar
# analigous
# asertions
# VeniceItalywhich
# bcandiadates
# wouldntt
# fafe
# stateNobody
# pearsons
# fouset
# acheievment
# traitsproblems
# exprssion
# stgart
# courseaccording
# divorcedwont
# diesal
# tthree
# customizible
# canindates
# incovience
# centeralized
# Colomia
# peopleanimals
# missread
# wishdream
# FutureÃÂ
# conspirists
# stuudent
# adventful
# turnmoil
# reserchers
# informationthe
# Manveuring
# gonebut
# eyesnose
# campaigh
# absolutlly
# Resive
# aficient
# tuored
# importantSeagoing
# licence
# summerdesigned
# electorsl
# democraticPlumerParagraph9
# metersand
# astroughnaughts
# occaisional
# detentionsaturday
# invaled
# descissons
# disturbites
# offifce
# drempt
# automakewrs
# comblogteendistracteddriving
# immensily
# tacher
# NEEDA
# systums
# therell
# justifyed
# objacts
# supisously
# voying
# foodHey
# perosnal
# placeTaking
# liscene
# perment
# smogor
# deamed
# exploids
# scood
# reasonthey
# consiswts
# rarerly
# perticapate
# camrer
# secterts
# expains
# revealved
# nigitives
# brcause
# accdient
# mimicated
# becaise
# sidiment
# improvent
# pulmonar
# adviseand
# innocations
# thatabout
# trasnportation
# bestfriends
# Vus
# amospheric
# classbecause
# unlikelu
# electons
# lattest
# somothing
# ailens
# compremise
# globaly
# capabities
# 1150
# goingon
# saysIs
# allit
# peogram
# stufying
# cattletravel
# accient
# EarthVenus
# frienddhips
# blnkets
# Aritcle
# proveing
# asvwell
# Pargraph
# htings
# dramaic
# emations
# EightyThree
# biffrents
# esier
# Kennedyopposing
# shootss
# technologycalled
# HOTEL_NAMEThey
# posslbe
# idenfied
# onyourself
# navagate
# riera
# docomplete
# UNRRAthe
# educationStudents
# extravogant
# eceeds
# respersatition
# conspiricy
# historcal
# freguent
# Completeing
# legislatorsnare
# surrondings
# daliy
# usaly
# naking
# dowithout
# conclusionpeople
# Sportsstudent
# teacherdeigned
# benefices
# abstacle
# nondriven
# acknolaged
# causeing
# Eletororal
# teachersprofessor
# challeging
# securitylike
# Desriable
# suceesed
# mehod
# buckinghem
# sieastem
# 3not
# UIm
# themand
# mayority
# michigans
# eown
# assiged
# sayinglook
# mabby
# hasHoweverthe
# delclares
# trype
# claaified
# elcotors
# com3220cellphonesbanneddriving
# SEMIself
# voleyball
# wnating
# evere
# desoite
# expain
# TextingDrive
# 228000
# gadet
# classmatesbut
# weeknesses
# dualtask
# Bogste
# accuerate
# certianty
# fuelsaving
# majoritymost
# rockgasor
# possabilty
# intamated
# wrinking
# multiplechoice
# sespecilly
# osculate
# nonrequired
# wiled
# 1960segregationists
# 1885
# 800F
# utilziled
# matural
# easeir
# manducatures
# fuctions
# crurcial
# exerciseactivity
# activitie
# storngly
# alothough
# things3
# nearrecord
# Venusparagraoh
# themselvesMost
# mearures
# walkrode
# imcoming
# accsessability
# II7
# surfce
# desgning
# beaucse
# orbircularis
# compaies
# feelingsopinions
# softwat
# univerce
# nauseousbegan
# PLUGIN
# timealso
# elecetoral
# endofsemester
# viriuses
# Huangeven
# regaurds
# sientiste
# surprice
# chouse
# segregtions
# countuine
# unfairto
# nationwidebut
# drivermanufactorer
# accidentsdebates
# writhen
# alliens
# awaste
# shehe
# resourcesand
# beasy
# ailen
# culpret
# finking
# yetto
# comfront
# pontiental
# sadbecause
# Secound
# concequences
# prosepct
# allwhile
# Collumist
# eyesThats
# destressers
# 678
# Disigning
# suprieor
# communicateand
# decovered
# 712
# threemile
# partialautonomous
# manipulationand
# hassal
# runningcatchingthrowing
# argumint
# presely
# changeing
# pleace
# prerequasite
# votedirectly
# adviceopinions
# technilogically
# teacherdesigned
# undoubtingly
# tranporstion
# spilt
# monthsdiscover
# shoudve
# pursit
# morer
# disires
# Advanvced
# apadted
# 1620
# badthen
# envokes
# polpuar
# scientificresearch
# meterors
# tremoendously
# 130in
# Generic_Nameand
# healthyand
# deathbyvehicle
# Fiftyseven
# prepered
# insurrence
# stresssed
# acshuly
# anatomty
# votedue
# sayingOur
# unaccurate
# shorly
# comparad
# presendential
# candidarte
# makingforcing
# diffrenf
# camerasgames
# 1pound
# prodominently
# ConclusionI
# votewhich
# 27peoplehad
# scaters
# bluried
# candidt
# sustsain
# talland
# appricate
# reapir
# onFrom
# maake
# Vaubanss
# fatalites
# ChampsElysees13
# Thousans
# obeserved
# gamephone
# Vehichles
# Witout
# shoice
# easeier
# comfortabe
# fromyou
# increadable
# unorderly
# techanically
# homein
# exepted
# freqeunt
# granpa
# years80
# image7
# preshere
# ThoughI
# safewise
# econany
# conclusioin
# 18The
# belimited
# faceit
# poltiacl
# Haungs
# 114
# destinguish
# intteract
# labelled
# thatsome
# undersatnds
# divinging
# 583
# Opinoins
# 275
# driveto
# polutin
# voteers
# adaft
# amagine
# plantsRosenthal
# annother
# 97percent
# wwwthezebracom
# forgein
# earlierabout
# nowaday
# purposly
# anciet
# nowGeneric_Name
# actial
# chooseAccording
# willthe
# lagest
# specialThis
# polyical
# phtos
# peoplewhich
# envirnmentand
# funneist
# selfefficient
# liabillty
# clubsactivities
# viliage
# Anybodyvoted
# spacraft
# oainting
# 201
# partticularly
# anothert
# goalstouchdownseven
# camppaign
# 403pm
# votewas
# twinthat
# calculas
# relpacing
# Ascertainmet
# bullingno
# idividuals
# manday
# manequally
# whywe
# USThere
# 341
# dadsurely
# realtiy
# ultimatelly
# theorpy
# articlecalled
# pharo
# nondemocractic
# exsmoker
# Anthore
# 266
# 30006000
# 200
# hipocrytical
# winSo
# systembefore
# inetersting
# nondemocratix
# Presidentbut
# Becaus
# cirtan
# cerntain
# experiecs
# conservaative
# Altought
# displats
# thatsegregationist
# recives
# knowlodge
# enviorments
# intirely
# activityÃÂs
# notsaying
# Especally
# electorsin
# 144
# learningnot
# studentswho
# highwaysource
# trush
# popele
# stressanger
# atyou
# movey
# vevus
# passioniate
# 1360
# Reular
# eloctoral
# numberone
# knwoledge
# studentdirected
# goies
# Reasearchers
# OutcomeEveryones
# sayes
# deveopments
# pluerality
# trew
# avendture
# stres
# pollot
# shorttime
# disgussed
# anuimals
# imagesthe
# thirs
# wontt
# aboslute
# cityDuffer
# prisendent
# remperature
# crowdsexpands
# studentsdesigns
# dictraction
# natioal
# disicions
# oppertunitities
# everydayto
# beaucsue
# ocnditions
# gradutate
# viache
# Accorrding
# oppinons
# beganning
# thatbecause
# witer
# comentrytextingredlight_n_3915817
# Coboy
# debrie
# famililys
# Useing
# Parthonon
# vehicl
# rexceeded
# helpand
# chaleng
# Determie
# unvalid
# comromise
# comuting
# perceptative
# leadershipindependence
# proplably
# languageThat
# Rivaled
# dangercan
# probaley
# fealing
# Havong
# anythingWrong
# responsabillities
# featurebut
# metters
# countris
# rushmore
# sportbecause
# nosmart
# acrynoms
# Schlolars
# woukd
# finecongestion
# clombians
# westThe
# presidentisl
# chhose
# amaking
# distantParagraph
# Ifwe
# unavaliable
# modifty
# chmaber
# woluld
# recogniton
# entireiety
# persontoperson
# senatoris
# Plazaselsky
# technicaly
# similliar
# prons
# Chosing
# candidater
# responblitiltes
# inocense
# citiies
# interset
# prombles
# convinsing
# mythicalwas
# ÃÅf
# veyr
# speicies
# declaired
# expenssive
# youwhere
# propposed
# indiviually
# decadaes
# schoolsbusinesses
# 330pm
# camapigning
# furtherer
# venuses
# movmentsin
# reubtes
# percieves
# studebts
# limitting
# genearal
# drousy
# truning
# expenive
# 79
# resoucesknowledge
# toneTo
# occurane
# manufactuerer
# satisfided
# activityfor
# fancing
# carfreeday
# controlers
# oportuinite
# hospidible
# heavely
# 80s
# beingt
# rocksgas
# populariity
# metter
# Representativese
# sge
# Eart
# producethem
# nerver
# happy9
# traportations
# manufacteror
# omly
# riverBUT
# pursuasive
# com100distracteddrivingfactsstatisticsfor2018
# demoractic
# articlesthe
# acticles
# personbut
# studdy
# videagraphy
# occumpany
# lears
# pollutionParis
# paprgraph
# DriveLess
# projectsassignments
# GBwhich
# matterial
# imprinited
# Whn
# problemsissues
# discovred
# vbest
# conserns
# ewill
# skillbased
# pursui
# Italty
# aswesome
# limitdating
# unfortinit
# candate
# 140
# hepl
# eligle
# payoh
# frefer
# govriskydrivingdistracteddriving
# personhit
# fifityfive
# prohibeded
# Veniceitaly
# prasident
# hasslefree
# troubl
# ypure
# lifealtering
# destorys
# mayorsand
# surposed
# areayou
# couold
# destricted
# particutate
# condutions
# probibly
# scapecraft
# presdidents
# nned
# onethousand
# Venussuch
# huamn
# Bushand
# wonderingthe
# legestlature
# ConstitutionThe
# displyas
# Wellno
# esays
# taugh
# countryarea
# chnce
# occursstarts
# winng
# stopandgo
# cominfocartextinganddriving
# govoner
# MexicanAmerican
# Getiing
# excersizing
# leftr
# companiesor
# learnerwhich
# algorrithmms
# friendsAnother
# limired
# textingor
# overwhelmeed
# extroadinary
# votesmeaning
# tounfair
# rarley
# earthsolar
# jan28
# portraied
# specailize
# werid
# drinving
# Thenthe
# emprove
# secondsdo
# throuroughly
# balme
# someparts
# sighswhats
# Exerice
# studehts
# regulaters
# Litilarcery
# achool
# voteElectoral
# Aruto
# phoneetc
# couciling
# thatthat
# hunman
# Vinvis
# weigth
# 103
# activitly
# elecotors
# Itcanwait
# companysaid
# Loisiana
# incerases
# explaine
# rwal
# dangeris
# Hauang
# coupld
# 765
# historicalit
# DisorderADHD
# thinig
# belivable
# pictyures
# enormousy
# mediabutat
# Butso
# delegationwhich
# sall
# heavly
# oppertunitys
# valleies
# electrecity
# balace
# remerkable
# cellphonesinternet
# verious
# Nextly
# argree
# misfunction
# negtive
# uncompletely
# negatuve
# homeI
# 21yearold
# invesigations
# surtain
# procrasitnation
# subburban
# peoplae
# electorsalthough
# votesSo
# populer
# requier
# collaborationteam
# seventyseven
# transregionally
# eay
# ecosystemcommunity
# technolopgy
# fascrinated
# statesWe
# guidless
# importantlike
# dreppesion
# veicle
# massesand
# somethingI
# mmake
# sbout
# overvoard
# togeathere
# orgglobal20190205inemergingeconomiessmartphoneadoptionhasgrownmorequicklyamongyoungergenerations
# simalerates
# bennifit
# aclock
# supportedforms
# 462
# optionperspective
# Secondlysometimes
# nonmorning
# amental
# guidingbut
# paine
# stanger
# youwhich
# fortyseven
# helpfulmore
# reserached
# Stalles
# 1896
# emetions
# gardean
# regretpassion
# summerized
# accunization
# tecgnology
# tallk
# segregationalists
# schoolwe
# activitiesopportunities
# atmosphereVenus
# 2013New
# fullfiling
# construcetive
# unssesry
# accountible
# syntem
# achevied
# efficentaly
# basketballand
# opportiunity
# Statesand
# 570
# bumpscracks
# treansitions
# esprecially
# quickily
# wrinkiling
# selfmade
# TeenSafe
# Indefennsible
# stangers
# cummunication
# interneta
# oppion
# C02
# Commerece
# challangeing
# worksso
# Initialy
# wrried
# collegen
# encdoing
# THese
# differet
# coultures
# percentSource
# anvinted
# theirnwill
# 3carfree
# horribale
# fdrive
# definenly
# collabrate
# returnung
# expeirment
# Regisiter
# 2014
# Neerthe
# disabilitiescan
# Driverlesss
# anxioius
# imaginaiton
# ansewer
# suidcides
# proseger
# parcisepte
# patenually
# refelct
# carinsurance
# edupressreleasesarchives2000releasespress07242000
# actived
# pollutionwe
# accsadentaly
# descripes
# wasste
# presised
# supposably
# descions
# becaude
# Lastlythey
# Besidesits
# saidWhen
# drivway
# weelGM
# 1940s
# Coldnights
# exploning
# presidenrt
# roadnot
# knowow
# stes
# guidenscounsler
# paragraphes
# smlie
# Oppontens
# rotatiing
# onlinebased
# complt
# eaier
# exoressive
# 4See
# fiiting
# eartha
# TwentyFive
# versource
# actullally
# fuals
# effection
# emoyion
# nowlike
# dobt
# thereOkay
# aboiut
# begaN
# exstensive
# likeOne
# onor
# advcentures
# desition
# breathilizer
# manufactuerers
# eman
# Columbua
# mahawk
# 7051215
# ownfullymay
# incounclution
# percice
# districtS1P2
# particepate
# decaring
# branlawfirm
# assignmentas
# andpositve
# boerd
# 40minutes
# 27
# 1In
# Comercials
# dtarred
# campianes
# aresome
# dobut
# muesems
# coursenot
# indicident
# wieghed
# wachtman
# buyiinh
# genarations
# regualrs
# AlsoI
# wanr
# nuon
# elecrtecity
# eletcronic
# porvide
# sciencestis
# earthquakaker
# drivencars
# comepletely
# reqquired
# hapens
# faroff
# ourselvesbut
# madefor
# coomunication
# similing
# teacherget
# whyone
# earDo
# mentalphysical
# soppose
# mustake
# Thereforetheyll
# happysadangrysurpriseshockdisgust
# majoity
# citationticket
# acticities
# correcthy
# counrtries
# emmissons
# curuption
# homeworkesports
# 100in
# desenics
# youc
# foused
# cashsrapped
# siteseeingyou
# sewd
# changesaid
# faceParagraph5This
# wrond
# gatting
# certifcations
# poultion
# Communtities
# theas
# automatical
# notand
# apractical
# CellphoneUse
# occurung
# fahreheit
# optionand
# realitymany
# bacuse
# preffer
# Implomenting
# trustmake
# Citize
# diccusing
# educatoin
# themselveswould
# childerm
# distracction
# didntt
# dectration
# instuctions
# exacli
# biggerthan
# learninga
# ketp
# 20yearold
# comturies
# liscnes
# distan
# dressand
# 1517
# represenetives
# semiautnomous
# 715
# inited
# vaped
# formss
# thosde
# stlight
# baseballboxingreadingwhittlingand
# deprrison
# DCis
# simmiler
# suisides
# spontaneousness
# abale
# whtas
# flass
# preograms
# structers
# badThere
# meants
# herhimself
# authros
# Ananchronismaccording
# reilf
# pedstrian
# extremelly
# toltally
# IDaho
# fukky
# drivertime
# ciricular
# jobparents
# Cydonis
# statesEach
# doingit
# greduate
# uptopar
# wondent
# president2
# unexistent
# uncourages
# situsations
# nukul
# acuizations
# gohave
# taskoriented
# contridicts
# importanced
# airDuffer
# regongnize
# defently
# interrup
# Theese
# benefial
# advisecan
# exprssions
# Companythis
# excedes
# undertsnding
# imprees
# valcanos
# Inturn
# Presidenet
# conclusiongetting
# purchace
# itselve
# aicd
# merchury
# communitcate
# thibk
# byou
# Faithfullness
# ethoes
# Aerinautics
# prereceived
# dirrectly
# esample
# domany
# mid90s
# tactict
# permenently
# studystudy
# decussed
# aserations
# WHOOOSH
# awareyou
# casst
# analougous
# selfmotivated
# butIf
# exspression
# garentee
# Noitifcations
# dangoroue
# landfom
# dreiverless
# thnings
# surrondeed
# usinf
# characeristics
# Admendment
# felloe
# Veiw
# considerinf
# threir
# 1997Twenty
# irresponsable
# joind
# eatures
# Elecetoral
# optionopinion
# p10
# noticepresidents
# incarentertainment
# oppisite
# nowin
# baseballl
# votegot
# Represenstatives
# studnet
# atomoshere
# loudoun
# meit
# qualificatied
# aposed
# manufactorers
# favoritem
# 1888
# votesnow
# remendous
# streetsand
# casses
# ÃÂfalse
# coputer
# elecction
# pregent
# worldside
# Stuadents
# ambicouse
# presidentia
# submerne
# emotionaly
# 55MPH
# sickhandicapped
# responsiblilty
# threebecause
# interracting
# posibaly
# tellls
# diffference
# morningt
# invain
# statepartys
# minutessorry
# discouaragement
# evalutate
# himWhy
# classesand
# argung
# irrationalits
# geneuine
# Unquestibily
# uneveiled
# challeange
# acomidation
# vews
# saidWell
# shouldor
# knowldege
# articlewhy
# unquine
# bbecause
# Drivesafe
# Chicfila
# daysweeksmounthsor
# excpecially
# ifsands
# PLain
# Studentdesigned
# imrovement
# AFLCIOthanks
# communitie
# pargargraph
# handwrittting
# laditue
# argumental
# purpuse
# eveyrthing
# soccerfootballmedia
# factial
# outoftouch
# globla
# accumilated
# plesant
# squarles
# greately
# benith
# beiieve
# sepreate
# commercialand
# electionparagraph
# perfectlyyou
# wirhh
# dislikesummer
# RomneyBecause
# technologhy
# eflaws
# 1car
# Scientis
# belife
# upond
# bringbut
# ogf
# dicisons
# citizend
# effecent
# sennsors
# sayingdoing
# anstronount
# thikn
# conclusionschools
# mealts
# neagtives
# photographgs
# deflict
# supposively
# alble
# gameboys
# facsal
# proess
# resricted
# learnig
# tookwatched
# reconmend
# questionsadvice
# proyect
# votes538
# funwhen
# comensate
# genertion
# Reasonings
# exlpore
# ecumaliated
# Caliornia
# knowign
# incoredge
# resuers
# manufacturerWaiting
# Doordash
# nonliberal
# bettrayedbut
# accorinding
# geosystems
# Althoughyour
# playedan
# smogSelsky
# exhuast
# artifitial
# tbis
# chalnging
# Floridashown
# leislatures
# intereesting
# notsodemoctratic
# initiatereplyor
# danguorse
# inisint
# curantly
# assitence
# Egyptin
# tansporation
# soultion
# privelidge
# electol
# Firse
# delima
# eartth
# descrimate
# dumby
# uncomforatble
# assticance
# presidentmany
# tourtamentsfencingboxingwe
# summarizeif
# Carsshould
# descreptions
# depemdent
# invole
# ellctoral
# rven
# sporst
# processnot
# WeThe
# naturalsaid
# unessacery
# drierless
# sudying
# adoults
# thatby
# onstar
# surfuce
# illfounded
# matoaca
# Refuring
# Mindplay
# aliencreated
# uesd
# PROPER_NAMEs
# showdow
# rummers
# beneficicial
# saidabolish
# norht
# Elcectoral
# acticity
# hafe
# comprimse
# stuents
# civilation
# outcomeTwo
# ocenas
# favour
# fineparagraph
# statesWhen
# promonate
# vintg
# undoubtely
# desiel
# vehcicles
# theiries
# Clombia
# ddegres
# that1
# alians
# comarable
# moviestv
# assignmentsmultiple
# understrand
# trueselves
# dumbies
# prsons
# annoyoing
# chiildren
# manfucaturing
# citazen
# idale
# Condress
# exteremely
# drivleress
# viewIt
# vitue
# Thirdi
# disavantages
# P10
# studieng
# coloubia
# provented
# vialotors
# extravegant
# compains
# JTrump
# therioes
# distranted
# halpful
# youyou
# doesntt
# shoundnt
# outguned
# transportaton
# elctoal
# workzones
# chooseso
# Farenheitand
# representaives
# Venesuala
# 600PM
# midC
# mentoined
# byIt
# stochiometry
# aboutteencrashes
# campaigm
# clubsprograms
# ginourmous
# starvingasked
# 4pedestrianbicycleand
# academicaly
# Stystem
# contriversial
# anachronism15
# questionstudent
# motoredvechile
# canidets
# electiong
# grademake
# wakework
# disgustedand
# thearpy
# saysIf
# humanss
# anways
# successivly
# scientests
# okanet
# contibutes
# kmwide
# capitals17
# mebut
# Driveress
# thatand
# cars57percent
# csre
# rageuos
# Anthother
# dangersous
# easylyknowing
# usig
# revenuepublic
# papre
# praticle
# lunchan
# 5Avoid
# importanty
# disadantages
# familyself
# finesfeesgas
# bullyied
# Everythng
# drivingi
# alduts
# unfairirrational
# propriate
# 416000
# sciantists
# Represetatives
# para2
# parlementary
# evena
# anicent
# unforutnetly
# pollutionits
# accidentyly
# questionsyou
# colled
# uprade
# ideasopinions
# Indefensive
# differentlywhich
# deabate
# lifeskill
# WWIthanks
# GreecePanamaChina
# devolope
# triy
# alterenative
# injuredhurt
# expreess
# holdes
# injuredamage
# asepcts
# likeme
# resoltuion
# scince
# Excercising
# endles
# conclousion
# honeslty
# youir
# projectsFor
# imbarrasing
# empolyees
# spacce
# exstenive
# explord
# relason
# bown
# understandimg
# thenbut
# morst
# techonologies
# IBMYP
# knowledgenot
# presentationlearn
# Itss
# paintning
# lazyiness
# rethorical
# discustfear
# conficence
# buolt
# deseves
# volleyballtabletennis
# drugsalcohol

# %%
def argmax(vec):
    # return the argmax as a python int
    _, idx = torch.max(vec, 1)
    return idx.item()

def prepare_seq_word2vec(sentence, embedding_map):
    return torch.tensor([embedding_map[token] for token in sentence], dtype=torch.long)

def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] for w in seq]
    return torch.tensor(idxs, dtype=torch.long)


# Compute log sum exp in a numerically stable way for the forward algorithm
def log_sum_exp(vec):
    max_score = vec[0, argmax(vec)]
    max_score_broadcast = max_score.view(1, -1).expand(1, vec.size()[1])
    return max_score + \
        torch.log(torch.sum(torch.exp(vec - max_score_broadcast)))

class BiLSTM_CRF(nn.Module):

    def __init__(self, tag_to_ix, embedding_dim, hidden_dim,  vocab_size=300000):
        # what is tag_to_ix? embedding_dim OK, hidden_dim what to set?
        
        super(BiLSTM_CRF, self).__init__()
        self.embedding_dim = embedding_dim
        self.hidden_dim = hidden_dim
        self.vocab_size = vocab_size
        self.tag_to_ix = tag_to_ix
        self.tagset_size = len(tag_to_ix)

        self.word_embeds = nn.Embedding(vocab_size, embedding_dim)
        self.word_embeds.weight = nn.Parameter(torch.from_numpy(gensim_model.vectors).float())
        # add a load from state dict
        
        self.lstm = nn.LSTM(embedding_dim, hidden_dim // 2,
                            num_layers=1, bidirectional=True)

        # Maps the output of the LSTM into tag space.
        self.hidden2tag = nn.Linear(hidden_dim, self.tagset_size)

        # Matrix of transition parameters.  Entry i,j is the score of
        # transitioning *to* i *from* j.
        self.transitions = nn.Parameter(
            torch.randn(self.tagset_size, self.tagset_size))

        # These two statements enforce the constraint that we never transfer
        # to the start tag and we never transfer from the stop tag
        self.transitions.data[tag_to_ix[START_TAG], :] = -10000
        self.transitions.data[:, tag_to_ix[STOP_TAG]] = -10000

        self.hidden = self.init_hidden()

    def init_hidden(self):
        return (torch.randn(2, 1, self.hidden_dim // 2),
                torch.randn(2, 1, self.hidden_dim // 2))

    def _forward_alg(self, feats):
        # Do the forward algorithm to compute the partition function
        init_alphas = torch.full((1, self.tagset_size), -10000.)
        # START_TAG has all of the score.
        init_alphas[0][self.tag_to_ix[START_TAG]] = 0.

        # Wrap in a variable so that we will get automatic backprop
        forward_var = init_alphas

        # Iterate through the sentence
        for feat in feats:
            print(feat)
            break
            alphas_t = []  # The forward tensors at this timestep
            for next_tag in range(self.tagset_size):
                # broadcast the emission score: it is the same regardless of
                # the previous tag
                emit_score = feat[next_tag].view(
                    1, -1).expand(1, self.tagset_size)
                # the ith entry of trans_score is the score of transitioning to
                # next_tag from i
                trans_score = self.transitions[next_tag].view(1, -1)
                # The ith entry of next_tag_var is the value for the
                # edge (i -> next_tag) before we do log-sum-exp
                next_tag_var = forward_var + trans_score + emit_score
                # The forward variable for this tag is log-sum-exp of all the
                # scores.
                alphas_t.append(log_sum_exp(next_tag_var).view(1))
            forward_var = torch.cat(alphas_t).view(1, -1)
        terminal_var = forward_var + self.transitions[self.tag_to_ix[STOP_TAG]]
        alpha = log_sum_exp(terminal_var)
        return alpha

    def _get_lstm_features(self, sentence):
        self.hidden = self.init_hidden()
        embeds = self.word_embeds(sentence).view(len(sentence), 1, -1)
        lstm_out, self.hidden = self.lstm(embeds, self.hidden)
        lstm_out = lstm_out.view(len(sentence), self.hidden_dim)
        lstm_feats = self.hidden2tag(lstm_out)
        return lstm_feats

    def _score_sentence(self, feats, tags):
        # Gives the score of a provided tag sequence
        score = torch.zeros(1)
        tags = torch.cat([torch.tensor([self.tag_to_ix[START_TAG]], dtype=torch.long), tags])
        for i, feat in enumerate(feats):
            score = score + \
                self.transitions[tags[i + 1], tags[i]] + feat[tags[i + 1]]
        score = score + self.transitions[self.tag_to_ix[STOP_TAG], tags[-1]]
        return score

    def _viterbi_decode(self, feats):
        backpointers = []

        # Initialize the viterbi variables in log space
        init_vvars = torch.full((1, self.tagset_size), -10000.)
        init_vvars[0][self.tag_to_ix[START_TAG]] = 0

        # forward_var at step i holds the viterbi variables for step i-1
        forward_var = init_vvars
        for feat in feats:
            bptrs_t = []  # holds the backpointers for this step
            viterbivars_t = []  # holds the viterbi variables for this step

            for next_tag in range(self.tagset_size):
                # next_tag_var[i] holds the viterbi variable for tag i at the
                # previous step, plus the score of transitioning
                # from tag i to next_tag.
                # We don't include the emission scores here because the max
                # does not depend on them (we add them in below)
                next_tag_var = forward_var + self.transitions[next_tag]
                best_tag_id = argmax(next_tag_var)
                bptrs_t.append(best_tag_id)
                viterbivars_t.append(next_tag_var[0][best_tag_id].view(1))
            # Now add in the emission scores, and assign forward_var to the set
            # of viterbi variables we just computed
            forward_var = (torch.cat(viterbivars_t) + feat).view(1, -1)
            backpointers.append(bptrs_t)

        # Transition to STOP_TAG
        terminal_var = forward_var + self.transitions[self.tag_to_ix[STOP_TAG]]
        best_tag_id = argmax(terminal_var)
        path_score = terminal_var[0][best_tag_id]

        # Follow the back pointers to decode the best path.
        best_path = [best_tag_id]
        for bptrs_t in reversed(backpointers):
            best_tag_id = bptrs_t[best_tag_id]
            best_path.append(best_tag_id)
        # Pop off the start tag (we dont want to return that to the caller)
        start = best_path.pop()
        assert start == self.tag_to_ix[START_TAG]  # Sanity check
        best_path.reverse()
        return path_score, best_path

    def neg_log_likelihood(self, sentence, tags):
        feats = self._get_lstm_features(sentence)
        forward_score = self._forward_alg(feats)
        gold_score = self._score_sentence(feats, tags)
        return forward_score - gold_score

    def forward(self, sentence):  # dont confuse this with _forward_alg above.
        # Get the emission scores from the BiLSTM
        lstm_feats = self._get_lstm_features(sentence)

        # Find the best path, given the features.
        score, tag_seq = self._viterbi_decode(lstm_feats)
        return score, tag_seq

# %%
START_TAG = "<START>"
STOP_TAG = "<STOP>"
EMBEDDING_DIM = 300 # TODO need to set this to be the same as the dimension of the vectors you use
HIDDEN_DIM = 4

# Make up some training data
training_data = [(
    "the wall street journal reported today that apple corporation made money".split(),
    "B I I I O O O B I O O".split()
), (
    "georgia tech is a university in georgia".split(),
    "B I O O O O B".split()
)]
word_to_ix = {}
for sentence, tags in training_data:
    for word in sentence:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)

tag_to_ix = {"B": 0, "I": 1, "O": 2, START_TAG: 3, STOP_TAG: 4}


model = BiLSTM_CRF(tag_to_ix, EMBEDDING_DIM, HIDDEN_DIM, len(word_to_ix))
optimizer = optim.SGD(model.parameters(), lr=0.01, weight_decay=1e-4)

# %%
for epoch in range(
        300):  # again, normally you would NOT do 300 epochs, it is toy data
    for sentence, tags in training_data:

        # Step 1. Remember that Pytorch accumulates gradients.
        # We need to clear them out before each instance
        model.zero_grad()

        # Step 2. Get our inputs ready for the network, that is,
        # turn them into Tensors of word indices.
        sentence_in = prepare_sequence(sentence, word_to_ix)
        sentence_in = prepare_seq_word2vec(sentence, embedding_map)
        print(sentence_in)
        targets = torch.tensor([tag_to_ix[t] for t in tags], dtype=torch.long)

        # Step 3. Run our forward pass.
        loss = model.neg_log_likelihood(sentence_in, targets)

        # Step 4. Compute the loss, gradients, and update the parameters by
        # calling optimizer.step()
        loss.backward()
        optimizer.step()
    break
# Out:
# tensor([   11,  2334,  1482,  8977,   343,   205,     3, 13467,  6207,   107,
#           237])
# tensor([-0.0513, -0.1467,  0.3591, -0.1300, -0.0219],
#        grad_fn=<UnbindBackward0>)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <module>
#       9 # Step 2. Get our inputs ready for the network, that is,
#      10 # turn them into Tensors of word indices.
#      11 sentence_in = prepare_sequence(sentence, word_to_ix)
# ---> 12 sentence_in = prepare_seq_word2vec(sentence, embedding_map)
#      13 print(sentence_in)
#      14 targets = torch.tensor([tag_to_ix[t] for t in tags], dtype=torch.long)
#
# Input In [29], in prepare_seq_word2vec(sentence, embedding_map)
#       6 def prepare_seq_word2vec(sentence, embedding_map):
# ----> 7     return torch.tensor([embedding_map[token] for token in sentence], dtype=torch.long)
#
# Input In [29], in <listcomp>(.0)
#       6 def prepare_seq_word2vec(sentence, embedding_map):
# ----> 7     return torch.tensor([embedding_map[token] for token in sentence], dtype=torch.long)
#
# KeyError: 'a'

# %%
from gensim.test.utils import common_texts
from gensim.models import Word2Vec

# %%
def generate_embedding_matrix():
    # should generate an embedding matrix that is the size of the vocab each time...
    # we need to save this lol
    pass
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <module>
#       1 import gensim
# ----> 2 model = gensim.models.KeyedVectors.load_word2vec_format('path/to/file')
#       3 weights = torch.FloatTensor(model.vectors)
#
# File ~/opt/anaconda3/envs/argument-mining/lib/python3.8/site-packages/gensim/models/keyedvectors.py:1629, in KeyedVectors.load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1582 @classmethod
#    1583 def load_word2vec_format(
#    1584         cls, fname, fvocab=None, binary=False, encoding='utf8', unicode_errors='strict',
#    1585         limit=None, datatype=REAL, no_header=False,
#    1586     ):
#    1587     """Load KeyedVectors from a file produced by the original C word2vec-tool format.
#    1588
#    1589     Warnings
#    (...)
#    1627
#    1628     """
# -> 1629     return _load_word2vec_format(
#    1630         cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
#    1631         limit=limit, datatype=datatype, no_header=no_header,
#    1632     )
#
# File ~/opt/anaconda3/envs/argument-mining/lib/python3.8/site-packages/gensim/models/keyedvectors.py:1955, in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header, binary_chunk_size)
#    1952             counts[word] = int(count)
#    1954 logger.info("loading projection weights from %s", fname)
# -> 1955 with utils.open(fname, 'rb') as fin:
#    1956     if no_header:
#    1957         # deduce both vocab_size & vector_size from 1st pass over file
#    1958         if binary:
#
# File ~/opt/anaconda3/envs/argument-mining/lib/python3.8/site-packages/smart_open/smart_open_lib.py:188, in open(uri, mode, buffering, encoding, errors, newline, closefd, opener, ignore_ext, compression, transport_params)
#     185 if transport_params is None:
#     186     transport_params = {}
# --> 188 fobj = _shortcut_open(
#     189     uri,
#     190     mode,
#     191     compression=compression,
#     192     buffering=buffering,
#     193     encoding=encoding,
#     194     errors=errors,
#     195     newline=newline,
#     196 )
#     197 if fobj is not None:
#     198     return fobj
#
# File ~/opt/anaconda3/envs/argument-mining/lib/python3.8/site-packages/smart_open/smart_open_lib.py:361, in _shortcut_open(uri, mode, compression, buffering, encoding, errors, newline)
#     358 if errors and 'b' not in mode:
#     359     open_kwargs['errors'] = errors
# --> 361 return _builtin_open(local_path, mode, buffering=buffering, **open_kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path/to/file'

# %%
Word2Vec.vectors
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <module>
# ----> 1 Word2Vec.vectors
#
# AttributeError: type object 'Word2Vec' has no attribute 'vectors'

# %%
# Out:
# /var/folders/_6/scw_50_57tb8mmbpq6ylnl6w0000gn/T/ipykernel_2992/1384161003.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.text = df.text.str.replace('[^\w\s]','')

# %%
def get_word_ids(tokens, embedding_map, reduce_map):
    embedding_token_ids = [
        embedding_map[token] for token in tokens
    ]
    token_ids = [
        reduce_map[embedding_token_id] for embedding_token_id in embedding_token_ids
    ]
    return token_ids

# %%
get_word_ids(['Hi my name is Yousef'], key_to_index)

# %%
key_to_index = model.key_to_index

# %%
path = '../../data/bio/Persuade_postprocessed.json'
import pandas as pd
df = pd.read_json(path)
df.text = df.text.str.replace('[^\w\s]','')
vocab = set(' '.join(df.text.values).split())

ids = [key_to_index[word] for word in set(text_split)]
# Out:
# /var/folders/_6/scw_50_57tb8mmbpq6ylnl6w0000gn/T/ipykernel_2992/2150507369.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.text = df.text.str.replace('[^\w\s]','')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <module>
#       4 df.text = df.text.str.replace('[^\w\s]','')
#       5 vocab = set(' '.join(df.text.values).split())
# ----> 7 ids = [key_to_index[word] for word in set(text_split)]
#
# NameError: name 'text_split' is not defined

# %%
len(ids)

# %%
from gensim.models import FastText

common_texts = ['Hi my name is Yousef.'.split()]
from gensim.test.utils import common_texts
model2 = FastText(vector_size=4, window=3, min_count=1, sentences=common_texts, epochs=10)

# %%
model2.wv.__dict__
# Out:
# {'vector_size': 4,
#  'index_to_key': ['system',
#   'graph',
#   'trees',
#   'user',
#   'minors',
#   'eps',
#   'time',
#   'response',
#   'survey',
#   'computer',
#   'interface',
#   'human'],
#  'next_index': 0,
#  'key_to_index': {'system': 0,
#   'graph': 1,
#   'trees': 2,
#   'user': 3,
#   'minors': 4,
#   'eps': 5,
#   'time': 6,
#   'response': 7,
#   'survey': 8,
#   'computer': 9,
#   'interface': 10,
#   'human': 11},
#  'vectors': array([[-0.0277314 , -0.01877754,  0.0140359 ,  0.00355452],
#         [ 0.00626689, -0.04813672,  0.05594172,  0.07846048],
#         [-0.08235919,  0.01859071,  0.01354989, -0.02779197],
#         [-0.06887284,  0.00654027,  0.00479901, -0.0286346 ],
#         [ 0.07342507, -0.0066566 , -0.02673712, -0.00220155],
#         [ 0.02733365, -0.06495033,  0.01261815, -0.00852403],
#         [ 0.07512262, -0.0081279 , -0.00192467, -0.02304782],
#         [-0.04446438,  0.05171199,  0.00654341,  0.00534294],
#         [ 0.01452866,  0.02735674,  0.03940941, -0.02064527],
#         [-0.0026324 , -0.03817194, -0.02007434,  0.00741352],
#         [ 0.0113926 , -0.00874304, -0.03574701,  0.00472042],
#         [ 0.02830744,  0.01806019, -0.03648039,  0.02306542]],
#        dtype=float32),
#  'norms': None,
#  'expandos': {'count': array([4, 3, 3, 3, 2, 2, 2, 2, 2, 2, 2, 2]),
#   'sample_int': array([396841800, 463795800, 463795800, 463795800, 579459574, 579459574,
#          579459574, 579459574, 579459574, 579459574, 579459574, 579459574],
#         dtype=uint32)},
#  'mapfile_path': None,
#  'min_n': 3,
#  'max_n': 6,
#  'bucket': 2000000,
#  'buckets_word': [array([ 577843,  796992,  410716,  298171, 1365014, 1338566, 1502105,
#           705564, 1815523,  467698,  350029,  223369,  750181, 1020056,
#           688338, 1354765, 1500233, 1459435], dtype=uint32),
#   array([ 606866, 1714185,  337403,  365161, 1700295, 1257365, 1650887,
#           920315, 1567620, 1780484,  215758, 1736948, 1848702,  128481],
#         dtype=uint32),
#   array([ 485437, 1197320,  561431,  487916,   74386, 1839573, 1004626,
#            56836,  543215, 1012756,  122014,  965700, 1461902,  445173],
#         dtype=uint32),
#   array([1339771,  876474, 1735640, 1857042, 1170932,  501362, 1556644,
#          1112181, 1981201,  742840], dtype=uint32),
#   array([1512081, 1193581,  703654, 1662652, 1609815, 1634216, 1361070,
#          1441895,  550755,  211779,  208528, 1057386,  840088, 1582449,
#           125789,  760149,   86385,  725444], dtype=uint32),
#   array([ 677246,  723575,  567275,  127225, 1150149, 1971742], dtype=uint32),
#   array([ 373532, 1815011, 1934322, 1659044, 1943145,  253156, 1258414,
#          1296042,  773628,  255579], dtype=uint32),
#   array([ 724938,  107323,  254993, 1534554,  546073, 1160139,  371628,
#           493158,  232795, 1200732,  229942, 1033887, 1608155,  259055,
#           737172, 1945059,  766122,  509979,  940250,  890988, 1127577,
#          1978420,  666558,  868281, 1860869,  455041], dtype=uint32),
#   array([1909271, 1767039,  334507,  872138, 1672037,  579305, 1299940,
#           517799,  917648,  181423, 1567714, 1996372,  866548, 1983607,
#          1468395, 1653895, 1388859, 1430911], dtype=uint32),
#   array([1361509,    7960,  635832,  821303,  603614,  900202,  690637,
#          1739323, 1336315,  274442, 1323738, 1263533,  512791, 1076185,
#           885364,  525682, 1118190,   52561,  979225, 1230821,  434219,
#            26267,  400575, 1248576,  404442,  742840], dtype=uint32),
#   array([ 481960,   13140, 1330851,  215299, 1107422, 1850849,   87529,
#          1512477,  738446, 1537972,  128278,  462037, 1248576, 1973970,
#          1631561, 1420574, 1196176,  137187, 1425664, 1037439, 1535288,
#           332865, 1899436,  367830,  711889,  255708, 1619270, 1506472,
#          1273890, 1514545], dtype=uint32),
#   array([1630484,  453115, 1790062, 1061888, 1914993,  755376,  915322,
#          1525004,  303314,  312436, 1178494, 1773551, 1718531, 1270280],
#         dtype=uint32)],
#  'vectors_vocab': array([[-0.01340568,  0.00591078,  0.12758374,  0.22523183],
#         [-0.23257375, -0.17792022,  0.16147181,  0.2243247 ],
#         [-0.1253857 , -0.09408429,  0.18451262, -0.03833678],
#         [-0.11341632,  0.16383694, -0.12151156, -0.04539765],
#         [ 0.07193237,  0.02480325, -0.20713237, -0.23621911],
#         [ 0.18279415,  0.12675655,  0.16894233,  0.01907164],
#         [ 0.15877226, -0.08513415, -0.02366003,  0.14421433],
#         [-0.18804094, -0.09840259, -0.18778956, -0.02325106],
#         [ 0.23846525, -0.18297876, -0.05834286, -0.04843989],
#         [ 0.20193493, -0.1482866 ,  0.00112159, -0.11884059],
#         [-0.24008876,  0.12518233, -0.21898964, -0.10979563],
#         [-0.0008775 , -0.00740454, -0.191531  ,  0.24036857]],
#        dtype=float32),
#  'vectors_ngrams': array([[ 0.16878772, -0.11919394, -0.19534728, -0.10075444],
#         [-0.04309317,  0.15711287, -0.02436498, -0.20404205],
#         [-0.08255851,  0.05005026,  0.15659463,  0.11428025],
#         ...,
#         [ 0.1943017 , -0.1197423 ,  0.08607841,  0.12445804],
#         [ 0.09043515, -0.04263142, -0.22345108, -0.12466013],
#         [-0.19872016, -0.22180456,  0.10834444,  0.09445775]],
#        dtype=float32),
#  'compatible_hash': True,
#  'vectors_vocab_lockf': array([1.], dtype=float32),
#  'vectors_ngrams_lockf': array([1.], dtype=float32),
#  'vectors_lockf': array([1.], dtype=float32)}

# %%
# Out:
# /var/folders/_6/scw_50_57tb8mmbpq6ylnl6w0000gn/T/ipykernel_41137/383823899.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.text = df.text.str.replace('[^\w\s]','')

# %%
# Out:
# 68705

# %%
ids = []
for word in set(text_split):
    if word in key_to_index:
        ids.append(key_to_index[word])
print(len(ids))
# Out:
# 34256
